# %% [markdown]
# Bulk Write 작업
#
# 이 가이드에서는 PyMongo의 대량 쓰기 작업 기능을 활용하는 방법을 설명합니다. 쓰기 작업을 일괄 적으로 실행하면 네트워크 왕복 횟수가 줄어들고 쓰기 처리량이 증가합니다.
#
# Bulk Insert
#
# 버전 2.6의 새로운 기능.
#
# 목록을 insert_many()메소드에 전달하여 document 배치를 삽입 할 수 있습니다. PyMongo는 MongoDB에서 허용하는 최대 메시지 크기를 기반으로 배치를 더 작은 하위 배치로 자동 분할하여 매우 큰 대량 삽입 작업을 지원합니다.

# %%
from pymongo import MongoClient
client = MongoClient()

# %%
db = client.bulk_example
db.bulk.insert_many(
    [{'i':i} for i in range(10000)]).inserted_ids
# Out:
# [ObjectId('5fcee5583090e67da89ca17e'),
#  ObjectId('5fcee5583090e67da89ca17f'),
#  ObjectId('5fcee5583090e67da89ca180'),
#  ObjectId('5fcee5583090e67da89ca181'),
#  ObjectId('5fcee5583090e67da89ca182'),
#  ObjectId('5fcee5583090e67da89ca183'),
#  ObjectId('5fcee5583090e67da89ca184'),
#  ObjectId('5fcee5583090e67da89ca185'),
#  ObjectId('5fcee5583090e67da89ca186'),
#  ObjectId('5fcee5583090e67da89ca187'),
#  ObjectId('5fcee5583090e67da89ca188'),
#  ObjectId('5fcee5583090e67da89ca189'),
#  ObjectId('5fcee5583090e67da89ca18a'),
#  ObjectId('5fcee5583090e67da89ca18b'),
#  ObjectId('5fcee5583090e67da89ca18c'),
#  ObjectId('5fcee5583090e67da89ca18d'),
#  ObjectId('5fcee5583090e67da89ca18e'),
#  ObjectId('5fcee5583090e67da89ca18f'),
#  ObjectId('5fcee5583090e67da89ca190'),
#  ObjectId('5fcee5583090e67da89ca191'),
#  ObjectId('5fcee5583090e67da89ca192'),
#  ObjectId('5fcee5583090e67da89ca193'),
#  ObjectId('5fcee5583090e67da89ca194'),
#  ObjectId('5fcee5583090e67da89ca195'),
#  ObjectId('5fcee5583090e67da89ca196'),
#  ObjectId('5fcee5583090e67da89ca197'),
#  ObjectId('5fcee5583090e67da89ca198'),
#  ObjectId('5fcee5583090e67da89ca199'),
#  ObjectId('5fcee5583090e67da89ca19a'),
#  ObjectId('5fcee5583090e67da89ca19b'),
#  ObjectId('5fcee5583090e67da89ca19c'),
#  ObjectId('5fcee5583090e67da89ca19d'),
#  ObjectId('5fcee5583090e67da89ca19e'),
#  ObjectId('5fcee5583090e67da89ca19f'),
#  ObjectId('5fcee5583090e67da89ca1a0'),
#  ObjectId('5fcee5583090e67da89ca1a1'),
#  ObjectId('5fcee5583090e67da89ca1a2'),
#  ObjectId('5fcee5583090e67da89ca1a3'),
#  ObjectId('5fcee5583090e67da89ca1a4'),
#  ObjectId('5fcee5583090e67da89ca1a5'),
#  ObjectId('5fcee5583090e67da89ca1a6'),
#  ObjectId('5fcee5583090e67da89ca1a7'),
#  ObjectId('5fcee5583090e67da89ca1a8'),
#  ObjectId('5fcee5583090e67da89ca1a9'),
#  ObjectId('5fcee5583090e67da89ca1aa'),
#  ObjectId('5fcee5583090e67da89ca1ab'),
#  ObjectId('5fcee5583090e67da89ca1ac'),
#  ObjectId('5fcee5583090e67da89ca1ad'),
#  ObjectId('5fcee5583090e67da89ca1ae'),
#  ObjectId('5fcee5583090e67da89ca1af'),
#  ObjectId('5fcee5583090e67da89ca1b0'),
#  ObjectId('5fcee5583090e67da89ca1b1'),
#  ObjectId('5fcee5583090e67da89ca1b2'),
#  ObjectId('5fcee5583090e67da89ca1b3'),
#  ObjectId('5fcee5583090e67da89ca1b4'),
#  ObjectId('5fcee5583090e67da89ca1b5'),
#  ObjectId('5fcee5583090e67da89ca1b6'),
#  ObjectId('5fcee5583090e67da89ca1b7'),
#  ObjectId('5fcee5583090e67da89ca1b8'),
#  ObjectId('5fcee5583090e67da89ca1b9'),
#  ObjectId('5fcee5583090e67da89ca1ba'),
#  ObjectId('5fcee5583090e67da89ca1bb'),
#  ObjectId('5fcee5583090e67da89ca1bc'),
#  ObjectId('5fcee5583090e67da89ca1bd'),
#  ObjectId('5fcee5583090e67da89ca1be'),
#  ObjectId('5fcee5583090e67da89ca1bf'),
#  ObjectId('5fcee5583090e67da89ca1c0'),
#  ObjectId('5fcee5583090e67da89ca1c1'),
#  ObjectId('5fcee5583090e67da89ca1c2'),
#  ObjectId('5fcee5583090e67da89ca1c3'),
#  ObjectId('5fcee5583090e67da89ca1c4'),
#  ObjectId('5fcee5583090e67da89ca1c5'),
#  ObjectId('5fcee5583090e67da89ca1c6'),
#  ObjectId('5fcee5583090e67da89ca1c7'),
#  ObjectId('5fcee5583090e67da89ca1c8'),
#  ObjectId('5fcee5583090e67da89ca1c9'),
#  ObjectId('5fcee5583090e67da89ca1ca'),
#  ObjectId('5fcee5583090e67da89ca1cb'),
#  ObjectId('5fcee5583090e67da89ca1cc'),
#  ObjectId('5fcee5583090e67da89ca1cd'),
#  ObjectId('5fcee5583090e67da89ca1ce'),
#  ObjectId('5fcee5583090e67da89ca1cf'),
#  ObjectId('5fcee5583090e67da89ca1d0'),
#  ObjectId('5fcee5583090e67da89ca1d1'),
#  ObjectId('5fcee5583090e67da89ca1d2'),
#  ObjectId('5fcee5583090e67da89ca1d3'),
#  ObjectId('5fcee5583090e67da89ca1d4'),
#  ObjectId('5fcee5583090e67da89ca1d5'),
#  ObjectId('5fcee5583090e67da89ca1d6'),
#  ObjectId('5fcee5583090e67da89ca1d7'),
#  ObjectId('5fcee5583090e67da89ca1d8'),
#  ObjectId('5fcee5583090e67da89ca1d9'),
#  ObjectId('5fcee5583090e67da89ca1da'),
#  ObjectId('5fcee5583090e67da89ca1db'),
#  ObjectId('5fcee5583090e67da89ca1dc'),
#  ObjectId('5fcee5583090e67da89ca1dd'),
#  ObjectId('5fcee5583090e67da89ca1de'),
#  ObjectId('5fcee5583090e67da89ca1df'),
#  ObjectId('5fcee5583090e67da89ca1e0'),
#  ObjectId('5fcee5583090e67da89ca1e1'),
#  ObjectId('5fcee5583090e67da89ca1e2'),
#  ObjectId('5fcee5583090e67da89ca1e3'),
#  ObjectId('5fcee5583090e67da89ca1e4'),
#  ObjectId('5fcee5583090e67da89ca1e5'),
#  ObjectId('5fcee5583090e67da89ca1e6'),
#  ObjectId('5fcee5583090e67da89ca1e7'),
#  ObjectId('5fcee5583090e67da89ca1e8'),
#  ObjectId('5fcee5583090e67da89ca1e9'),
#  ObjectId('5fcee5583090e67da89ca1ea'),
#  ObjectId('5fcee5583090e67da89ca1eb'),
#  ObjectId('5fcee5583090e67da89ca1ec'),
#  ObjectId('5fcee5583090e67da89ca1ed'),
#  ObjectId('5fcee5583090e67da89ca1ee'),
#  ObjectId('5fcee5583090e67da89ca1ef'),
#  ObjectId('5fcee5583090e67da89ca1f0'),
#  ObjectId('5fcee5583090e67da89ca1f1'),
#  ObjectId('5fcee5583090e67da89ca1f2'),
#  ObjectId('5fcee5583090e67da89ca1f3'),
#  ObjectId('5fcee5583090e67da89ca1f4'),
#  ObjectId('5fcee5583090e67da89ca1f5'),
#  ObjectId('5fcee5583090e67da89ca1f6'),
#  ObjectId('5fcee5583090e67da89ca1f7'),
#  ObjectId('5fcee5583090e67da89ca1f8'),
#  ObjectId('5fcee5583090e67da89ca1f9'),
#  ObjectId('5fcee5583090e67da89ca1fa'),
#  ObjectId('5fcee5583090e67da89ca1fb'),
#  ObjectId('5fcee5583090e67da89ca1fc'),
#  ObjectId('5fcee5583090e67da89ca1fd'),
#  ObjectId('5fcee5583090e67da89ca1fe'),
#  ObjectId('5fcee5583090e67da89ca1ff'),
#  ObjectId('5fcee5583090e67da89ca200'),
#  ObjectId('5fcee5583090e67da89ca201'),
#  ObjectId('5fcee5583090e67da89ca202'),
#  ObjectId('5fcee5583090e67da89ca203'),
#  ObjectId('5fcee5583090e67da89ca204'),
#  ObjectId('5fcee5583090e67da89ca205'),
#  ObjectId('5fcee5583090e67da89ca206'),
#  ObjectId('5fcee5583090e67da89ca207'),
#  ObjectId('5fcee5583090e67da89ca208'),
#  ObjectId('5fcee5583090e67da89ca209'),
#  ObjectId('5fcee5583090e67da89ca20a'),
#  ObjectId('5fcee5583090e67da89ca20b'),
#  ObjectId('5fcee5583090e67da89ca20c'),
#  ObjectId('5fcee5583090e67da89ca20d'),
#  ObjectId('5fcee5583090e67da89ca20e'),
#  ObjectId('5fcee5583090e67da89ca20f'),
#  ObjectId('5fcee5583090e67da89ca210'),
#  ObjectId('5fcee5583090e67da89ca211'),
#  ObjectId('5fcee5583090e67da89ca212'),
#  ObjectId('5fcee5583090e67da89ca213'),
#  ObjectId('5fcee5583090e67da89ca214'),
#  ObjectId('5fcee5583090e67da89ca215'),
#  ObjectId('5fcee5583090e67da89ca216'),
#  ObjectId('5fcee5583090e67da89ca217'),
#  ObjectId('5fcee5583090e67da89ca218'),
#  ObjectId('5fcee5583090e67da89ca219'),
#  ObjectId('5fcee5583090e67da89ca21a'),
#  ObjectId('5fcee5583090e67da89ca21b'),
#  ObjectId('5fcee5583090e67da89ca21c'),
#  ObjectId('5fcee5583090e67da89ca21d'),
#  ObjectId('5fcee5583090e67da89ca21e'),
#  ObjectId('5fcee5583090e67da89ca21f'),
#  ObjectId('5fcee5583090e67da89ca220'),
#  ObjectId('5fcee5583090e67da89ca221'),
#  ObjectId('5fcee5583090e67da89ca222'),
#  ObjectId('5fcee5583090e67da89ca223'),
#  ObjectId('5fcee5583090e67da89ca224'),
#  ObjectId('5fcee5583090e67da89ca225'),
#  ObjectId('5fcee5583090e67da89ca226'),
#  ObjectId('5fcee5583090e67da89ca227'),
#  ObjectId('5fcee5583090e67da89ca228'),
#  ObjectId('5fcee5583090e67da89ca229'),
#  ObjectId('5fcee5583090e67da89ca22a'),
#  ObjectId('5fcee5583090e67da89ca22b'),
#  ObjectId('5fcee5583090e67da89ca22c'),
#  ObjectId('5fcee5583090e67da89ca22d'),
#  ObjectId('5fcee5583090e67da89ca22e'),
#  ObjectId('5fcee5583090e67da89ca22f'),
#  ObjectId('5fcee5583090e67da89ca230'),
#  ObjectId('5fcee5583090e67da89ca231'),
#  ObjectId('5fcee5583090e67da89ca232'),
#  ObjectId('5fcee5583090e67da89ca233'),
#  ObjectId('5fcee5583090e67da89ca234'),
#  ObjectId('5fcee5583090e67da89ca235'),
#  ObjectId('5fcee5583090e67da89ca236'),
#  ObjectId('5fcee5583090e67da89ca237'),
#  ObjectId('5fcee5583090e67da89ca238'),
#  ObjectId('5fcee5583090e67da89ca239'),
#  ObjectId('5fcee5583090e67da89ca23a'),
#  ObjectId('5fcee5583090e67da89ca23b'),
#  ObjectId('5fcee5583090e67da89ca23c'),
#  ObjectId('5fcee5583090e67da89ca23d'),
#  ObjectId('5fcee5583090e67da89ca23e'),
#  ObjectId('5fcee5583090e67da89ca23f'),
#  ObjectId('5fcee5583090e67da89ca240'),
#  ObjectId('5fcee5583090e67da89ca241'),
#  ObjectId('5fcee5583090e67da89ca242'),
#  ObjectId('5fcee5583090e67da89ca243'),
#  ObjectId('5fcee5583090e67da89ca244'),
#  ObjectId('5fcee5583090e67da89ca245'),
#  ObjectId('5fcee5583090e67da89ca246'),
#  ObjectId('5fcee5583090e67da89ca247'),
#  ObjectId('5fcee5583090e67da89ca248'),
#  ObjectId('5fcee5583090e67da89ca249'),
#  ObjectId('5fcee5583090e67da89ca24a'),
#  ObjectId('5fcee5583090e67da89ca24b'),
#  ObjectId('5fcee5583090e67da89ca24c'),
#  ObjectId('5fcee5583090e67da89ca24d'),
#  ObjectId('5fcee5583090e67da89ca24e'),
#  ObjectId('5fcee5583090e67da89ca24f'),
#  ObjectId('5fcee5583090e67da89ca250'),
#  ObjectId('5fcee5583090e67da89ca251'),
#  ObjectId('5fcee5583090e67da89ca252'),
#  ObjectId('5fcee5583090e67da89ca253'),
#  ObjectId('5fcee5583090e67da89ca254'),
#  ObjectId('5fcee5583090e67da89ca255'),
#  ObjectId('5fcee5583090e67da89ca256'),
#  ObjectId('5fcee5583090e67da89ca257'),
#  ObjectId('5fcee5583090e67da89ca258'),
#  ObjectId('5fcee5583090e67da89ca259'),
#  ObjectId('5fcee5583090e67da89ca25a'),
#  ObjectId('5fcee5583090e67da89ca25b'),
#  ObjectId('5fcee5583090e67da89ca25c'),
#  ObjectId('5fcee5583090e67da89ca25d'),
#  ObjectId('5fcee5583090e67da89ca25e'),
#  ObjectId('5fcee5583090e67da89ca25f'),
#  ObjectId('5fcee5583090e67da89ca260'),
#  ObjectId('5fcee5583090e67da89ca261'),
#  ObjectId('5fcee5583090e67da89ca262'),
#  ObjectId('5fcee5583090e67da89ca263'),
#  ObjectId('5fcee5583090e67da89ca264'),
#  ObjectId('5fcee5583090e67da89ca265'),
#  ObjectId('5fcee5583090e67da89ca266'),
#  ObjectId('5fcee5583090e67da89ca267'),
#  ObjectId('5fcee5583090e67da89ca268'),
#  ObjectId('5fcee5583090e67da89ca269'),
#  ObjectId('5fcee5583090e67da89ca26a'),
#  ObjectId('5fcee5583090e67da89ca26b'),
#  ObjectId('5fcee5583090e67da89ca26c'),
#  ObjectId('5fcee5583090e67da89ca26d'),
#  ObjectId('5fcee5583090e67da89ca26e'),
#  ObjectId('5fcee5583090e67da89ca26f'),
#  ObjectId('5fcee5583090e67da89ca270'),
#  ObjectId('5fcee5583090e67da89ca271'),
#  ObjectId('5fcee5583090e67da89ca272'),
#  ObjectId('5fcee5583090e67da89ca273'),
#  ObjectId('5fcee5583090e67da89ca274'),
#  ObjectId('5fcee5583090e67da89ca275'),
#  ObjectId('5fcee5583090e67da89ca276'),
#  ObjectId('5fcee5583090e67da89ca277'),
#  ObjectId('5fcee5583090e67da89ca278'),
#  ObjectId('5fcee5583090e67da89ca279'),
#  ObjectId('5fcee5583090e67da89ca27a'),
#  ObjectId('5fcee5583090e67da89ca27b'),
#  ObjectId('5fcee5583090e67da89ca27c'),
#  ObjectId('5fcee5583090e67da89ca27d'),
#  ObjectId('5fcee5583090e67da89ca27e'),
#  ObjectId('5fcee5583090e67da89ca27f'),
#  ObjectId('5fcee5583090e67da89ca280'),
#  ObjectId('5fcee5583090e67da89ca281'),
#  ObjectId('5fcee5583090e67da89ca282'),
#  ObjectId('5fcee5583090e67da89ca283'),
#  ObjectId('5fcee5583090e67da89ca284'),
#  ObjectId('5fcee5583090e67da89ca285'),
#  ObjectId('5fcee5583090e67da89ca286'),
#  ObjectId('5fcee5583090e67da89ca287'),
#  ObjectId('5fcee5583090e67da89ca288'),
#  ObjectId('5fcee5583090e67da89ca289'),
#  ObjectId('5fcee5583090e67da89ca28a'),
#  ObjectId('5fcee5583090e67da89ca28b'),
#  ObjectId('5fcee5583090e67da89ca28c'),
#  ObjectId('5fcee5583090e67da89ca28d'),
#  ObjectId('5fcee5583090e67da89ca28e'),
#  ObjectId('5fcee5583090e67da89ca28f'),
#  ObjectId('5fcee5583090e67da89ca290'),
#  ObjectId('5fcee5583090e67da89ca291'),
#  ObjectId('5fcee5583090e67da89ca292'),
#  ObjectId('5fcee5583090e67da89ca293'),
#  ObjectId('5fcee5583090e67da89ca294'),
#  ObjectId('5fcee5583090e67da89ca295'),
#  ObjectId('5fcee5583090e67da89ca296'),
#  ObjectId('5fcee5583090e67da89ca297'),
#  ObjectId('5fcee5583090e67da89ca298'),
#  ObjectId('5fcee5583090e67da89ca299'),
#  ObjectId('5fcee5583090e67da89ca29a'),
#  ObjectId('5fcee5583090e67da89ca29b'),
#  ObjectId('5fcee5583090e67da89ca29c'),
#  ObjectId('5fcee5583090e67da89ca29d'),
#  ObjectId('5fcee5583090e67da89ca29e'),
#  ObjectId('5fcee5583090e67da89ca29f'),
#  ObjectId('5fcee5583090e67da89ca2a0'),
#  ObjectId('5fcee5583090e67da89ca2a1'),
#  ObjectId('5fcee5583090e67da89ca2a2'),
#  ObjectId('5fcee5583090e67da89ca2a3'),
#  ObjectId('5fcee5583090e67da89ca2a4'),
#  ObjectId('5fcee5583090e67da89ca2a5'),
#  ObjectId('5fcee5583090e67da89ca2a6'),
#  ObjectId('5fcee5583090e67da89ca2a7'),
#  ObjectId('5fcee5583090e67da89ca2a8'),
#  ObjectId('5fcee5583090e67da89ca2a9'),
#  ObjectId('5fcee5583090e67da89ca2aa'),
#  ObjectId('5fcee5583090e67da89ca2ab'),
#  ObjectId('5fcee5583090e67da89ca2ac'),
#  ObjectId('5fcee5583090e67da89ca2ad'),
#  ObjectId('5fcee5583090e67da89ca2ae'),
#  ObjectId('5fcee5583090e67da89ca2af'),
#  ObjectId('5fcee5583090e67da89ca2b0'),
#  ObjectId('5fcee5583090e67da89ca2b1'),
#  ObjectId('5fcee5583090e67da89ca2b2'),
#  ObjectId('5fcee5583090e67da89ca2b3'),
#  ObjectId('5fcee5583090e67da89ca2b4'),
#  ObjectId('5fcee5583090e67da89ca2b5'),
#  ObjectId('5fcee5583090e67da89ca2b6'),
#  ObjectId('5fcee5583090e67da89ca2b7'),
#  ObjectId('5fcee5583090e67da89ca2b8'),
#  ObjectId('5fcee5583090e67da89ca2b9'),
#  ObjectId('5fcee5583090e67da89ca2ba'),
#  ObjectId('5fcee5583090e67da89ca2bb'),
#  ObjectId('5fcee5583090e67da89ca2bc'),
#  ObjectId('5fcee5583090e67da89ca2bd'),
#  ObjectId('5fcee5583090e67da89ca2be'),
#  ObjectId('5fcee5583090e67da89ca2bf'),
#  ObjectId('5fcee5583090e67da89ca2c0'),
#  ObjectId('5fcee5583090e67da89ca2c1'),
#  ObjectId('5fcee5583090e67da89ca2c2'),
#  ObjectId('5fcee5583090e67da89ca2c3'),
#  ObjectId('5fcee5583090e67da89ca2c4'),
#  ObjectId('5fcee5583090e67da89ca2c5'),
#  ObjectId('5fcee5583090e67da89ca2c6'),
#  ObjectId('5fcee5583090e67da89ca2c7'),
#  ObjectId('5fcee5583090e67da89ca2c8'),
#  ObjectId('5fcee5583090e67da89ca2c9'),
#  ObjectId('5fcee5583090e67da89ca2ca'),
#  ObjectId('5fcee5583090e67da89ca2cb'),
#  ObjectId('5fcee5583090e67da89ca2cc'),
#  ObjectId('5fcee5583090e67da89ca2cd'),
#  ObjectId('5fcee5583090e67da89ca2ce'),
#  ObjectId('5fcee5583090e67da89ca2cf'),
#  ObjectId('5fcee5583090e67da89ca2d0'),
#  ObjectId('5fcee5583090e67da89ca2d1'),
#  ObjectId('5fcee5583090e67da89ca2d2'),
#  ObjectId('5fcee5583090e67da89ca2d3'),
#  ObjectId('5fcee5583090e67da89ca2d4'),
#  ObjectId('5fcee5583090e67da89ca2d5'),
#  ObjectId('5fcee5583090e67da89ca2d6'),
#  ObjectId('5fcee5583090e67da89ca2d7'),
#  ObjectId('5fcee5583090e67da89ca2d8'),
#  ObjectId('5fcee5583090e67da89ca2d9'),
#  ObjectId('5fcee5583090e67da89ca2da'),
#  ObjectId('5fcee5583090e67da89ca2db'),
#  ObjectId('5fcee5583090e67da89ca2dc'),
#  ObjectId('5fcee5583090e67da89ca2dd'),
#  ObjectId('5fcee5583090e67da89ca2de'),
#  ObjectId('5fcee5583090e67da89ca2df'),
#  ObjectId('5fcee5583090e67da89ca2e0'),
#  ObjectId('5fcee5583090e67da89ca2e1'),
#  ObjectId('5fcee5583090e67da89ca2e2'),
#  ObjectId('5fcee5583090e67da89ca2e3'),
#  ObjectId('5fcee5583090e67da89ca2e4'),
#  ObjectId('5fcee5583090e67da89ca2e5'),
#  ObjectId('5fcee5583090e67da89ca2e6'),
#  ObjectId('5fcee5583090e67da89ca2e7'),
#  ObjectId('5fcee5583090e67da89ca2e8'),
#  ObjectId('5fcee5583090e67da89ca2e9'),
#  ObjectId('5fcee5583090e67da89ca2ea'),
#  ObjectId('5fcee5583090e67da89ca2eb'),
#  ObjectId('5fcee5583090e67da89ca2ec'),
#  ObjectId('5fcee5583090e67da89ca2ed'),
#  ObjectId('5fcee5583090e67da89ca2ee'),
#  ObjectId('5fcee5583090e67da89ca2ef'),
#  ObjectId('5fcee5583090e67da89ca2f0'),
#  ObjectId('5fcee5583090e67da89ca2f1'),
#  ObjectId('5fcee5583090e67da89ca2f2'),
#  ObjectId('5fcee5583090e67da89ca2f3'),
#  ObjectId('5fcee5583090e67da89ca2f4'),
#  ObjectId('5fcee5583090e67da89ca2f5'),
#  ObjectId('5fcee5583090e67da89ca2f6'),
#  ObjectId('5fcee5583090e67da89ca2f7'),
#  ObjectId('5fcee5583090e67da89ca2f8'),
#  ObjectId('5fcee5583090e67da89ca2f9'),
#  ObjectId('5fcee5583090e67da89ca2fa'),
#  ObjectId('5fcee5583090e67da89ca2fb'),
#  ObjectId('5fcee5583090e67da89ca2fc'),
#  ObjectId('5fcee5583090e67da89ca2fd'),
#  ObjectId('5fcee5583090e67da89ca2fe'),
#  ObjectId('5fcee5583090e67da89ca2ff'),
#  ObjectId('5fcee5583090e67da89ca300'),
#  ObjectId('5fcee5583090e67da89ca301'),
#  ObjectId('5fcee5583090e67da89ca302'),
#  ObjectId('5fcee5583090e67da89ca303'),
#  ObjectId('5fcee5583090e67da89ca304'),
#  ObjectId('5fcee5583090e67da89ca305'),
#  ObjectId('5fcee5583090e67da89ca306'),
#  ObjectId('5fcee5583090e67da89ca307'),
#  ObjectId('5fcee5583090e67da89ca308'),
#  ObjectId('5fcee5583090e67da89ca309'),
#  ObjectId('5fcee5583090e67da89ca30a'),
#  ObjectId('5fcee5583090e67da89ca30b'),
#  ObjectId('5fcee5583090e67da89ca30c'),
#  ObjectId('5fcee5583090e67da89ca30d'),
#  ObjectId('5fcee5583090e67da89ca30e'),
#  ObjectId('5fcee5583090e67da89ca30f'),
#  ObjectId('5fcee5583090e67da89ca310'),
#  ObjectId('5fcee5583090e67da89ca311'),
#  ObjectId('5fcee5583090e67da89ca312'),
#  ObjectId('5fcee5583090e67da89ca313'),
#  ObjectId('5fcee5583090e67da89ca314'),
#  ObjectId('5fcee5583090e67da89ca315'),
#  ObjectId('5fcee5583090e67da89ca316'),
#  ObjectId('5fcee5583090e67da89ca317'),
#  ObjectId('5fcee5583090e67da89ca318'),
#  ObjectId('5fcee5583090e67da89ca319'),
#  ObjectId('5fcee5583090e67da89ca31a'),
#  ObjectId('5fcee5583090e67da89ca31b'),
#  ObjectId('5fcee5583090e67da89ca31c'),
#  ObjectId('5fcee5583090e67da89ca31d'),
#  ObjectId('5fcee5583090e67da89ca31e'),
#  ObjectId('5fcee5583090e67da89ca31f'),
#  ObjectId('5fcee5583090e67da89ca320'),
#  ObjectId('5fcee5583090e67da89ca321'),
#  ObjectId('5fcee5583090e67da89ca322'),
#  ObjectId('5fcee5583090e67da89ca323'),
#  ObjectId('5fcee5583090e67da89ca324'),
#  ObjectId('5fcee5583090e67da89ca325'),
#  ObjectId('5fcee5583090e67da89ca326'),
#  ObjectId('5fcee5583090e67da89ca327'),
#  ObjectId('5fcee5583090e67da89ca328'),
#  ObjectId('5fcee5583090e67da89ca329'),
#  ObjectId('5fcee5583090e67da89ca32a'),
#  ObjectId('5fcee5583090e67da89ca32b'),
#  ObjectId('5fcee5583090e67da89ca32c'),
#  ObjectId('5fcee5583090e67da89ca32d'),
#  ObjectId('5fcee5583090e67da89ca32e'),
#  ObjectId('5fcee5583090e67da89ca32f'),
#  ObjectId('5fcee5583090e67da89ca330'),
#  ObjectId('5fcee5583090e67da89ca331'),
#  ObjectId('5fcee5583090e67da89ca332'),
#  ObjectId('5fcee5583090e67da89ca333'),
#  ObjectId('5fcee5583090e67da89ca334'),
#  ObjectId('5fcee5583090e67da89ca335'),
#  ObjectId('5fcee5583090e67da89ca336'),
#  ObjectId('5fcee5583090e67da89ca337'),
#  ObjectId('5fcee5583090e67da89ca338'),
#  ObjectId('5fcee5583090e67da89ca339'),
#  ObjectId('5fcee5583090e67da89ca33a'),
#  ObjectId('5fcee5583090e67da89ca33b'),
#  ObjectId('5fcee5583090e67da89ca33c'),
#  ObjectId('5fcee5583090e67da89ca33d'),
#  ObjectId('5fcee5583090e67da89ca33e'),
#  ObjectId('5fcee5583090e67da89ca33f'),
#  ObjectId('5fcee5583090e67da89ca340'),
#  ObjectId('5fcee5583090e67da89ca341'),
#  ObjectId('5fcee5583090e67da89ca342'),
#  ObjectId('5fcee5583090e67da89ca343'),
#  ObjectId('5fcee5583090e67da89ca344'),
#  ObjectId('5fcee5583090e67da89ca345'),
#  ObjectId('5fcee5583090e67da89ca346'),
#  ObjectId('5fcee5583090e67da89ca347'),
#  ObjectId('5fcee5583090e67da89ca348'),
#  ObjectId('5fcee5583090e67da89ca349'),
#  ObjectId('5fcee5583090e67da89ca34a'),
#  ObjectId('5fcee5583090e67da89ca34b'),
#  ObjectId('5fcee5583090e67da89ca34c'),
#  ObjectId('5fcee5583090e67da89ca34d'),
#  ObjectId('5fcee5583090e67da89ca34e'),
#  ObjectId('5fcee5583090e67da89ca34f'),
#  ObjectId('5fcee5583090e67da89ca350'),
#  ObjectId('5fcee5583090e67da89ca351'),
#  ObjectId('5fcee5583090e67da89ca352'),
#  ObjectId('5fcee5583090e67da89ca353'),
#  ObjectId('5fcee5583090e67da89ca354'),
#  ObjectId('5fcee5583090e67da89ca355'),
#  ObjectId('5fcee5583090e67da89ca356'),
#  ObjectId('5fcee5583090e67da89ca357'),
#  ObjectId('5fcee5583090e67da89ca358'),
#  ObjectId('5fcee5583090e67da89ca359'),
#  ObjectId('5fcee5583090e67da89ca35a'),
#  ObjectId('5fcee5583090e67da89ca35b'),
#  ObjectId('5fcee5583090e67da89ca35c'),
#  ObjectId('5fcee5583090e67da89ca35d'),
#  ObjectId('5fcee5583090e67da89ca35e'),
#  ObjectId('5fcee5583090e67da89ca35f'),
#  ObjectId('5fcee5583090e67da89ca360'),
#  ObjectId('5fcee5583090e67da89ca361'),
#  ObjectId('5fcee5583090e67da89ca362'),
#  ObjectId('5fcee5583090e67da89ca363'),
#  ObjectId('5fcee5583090e67da89ca364'),
#  ObjectId('5fcee5583090e67da89ca365'),
#  ObjectId('5fcee5583090e67da89ca366'),
#  ObjectId('5fcee5583090e67da89ca367'),
#  ObjectId('5fcee5583090e67da89ca368'),
#  ObjectId('5fcee5583090e67da89ca369'),
#  ObjectId('5fcee5583090e67da89ca36a'),
#  ObjectId('5fcee5583090e67da89ca36b'),
#  ObjectId('5fcee5583090e67da89ca36c'),
#  ObjectId('5fcee5583090e67da89ca36d'),
#  ObjectId('5fcee5583090e67da89ca36e'),
#  ObjectId('5fcee5583090e67da89ca36f'),
#  ObjectId('5fcee5583090e67da89ca370'),
#  ObjectId('5fcee5583090e67da89ca371'),
#  ObjectId('5fcee5583090e67da89ca372'),
#  ObjectId('5fcee5583090e67da89ca373'),
#  ObjectId('5fcee5583090e67da89ca374'),
#  ObjectId('5fcee5583090e67da89ca375'),
#  ObjectId('5fcee5583090e67da89ca376'),
#  ObjectId('5fcee5583090e67da89ca377'),
#  ObjectId('5fcee5583090e67da89ca378'),
#  ObjectId('5fcee5583090e67da89ca379'),
#  ObjectId('5fcee5583090e67da89ca37a'),
#  ObjectId('5fcee5583090e67da89ca37b'),
#  ObjectId('5fcee5583090e67da89ca37c'),
#  ObjectId('5fcee5583090e67da89ca37d'),
#  ObjectId('5fcee5583090e67da89ca37e'),
#  ObjectId('5fcee5583090e67da89ca37f'),
#  ObjectId('5fcee5583090e67da89ca380'),
#  ObjectId('5fcee5583090e67da89ca381'),
#  ObjectId('5fcee5583090e67da89ca382'),
#  ObjectId('5fcee5583090e67da89ca383'),
#  ObjectId('5fcee5583090e67da89ca384'),
#  ObjectId('5fcee5583090e67da89ca385'),
#  ObjectId('5fcee5583090e67da89ca386'),
#  ObjectId('5fcee5583090e67da89ca387'),
#  ObjectId('5fcee5583090e67da89ca388'),
#  ObjectId('5fcee5583090e67da89ca389'),
#  ObjectId('5fcee5583090e67da89ca38a'),
#  ObjectId('5fcee5583090e67da89ca38b'),
#  ObjectId('5fcee5583090e67da89ca38c'),
#  ObjectId('5fcee5583090e67da89ca38d'),
#  ObjectId('5fcee5583090e67da89ca38e'),
#  ObjectId('5fcee5583090e67da89ca38f'),
#  ObjectId('5fcee5583090e67da89ca390'),
#  ObjectId('5fcee5583090e67da89ca391'),
#  ObjectId('5fcee5583090e67da89ca392'),
#  ObjectId('5fcee5583090e67da89ca393'),
#  ObjectId('5fcee5583090e67da89ca394'),
#  ObjectId('5fcee5583090e67da89ca395'),
#  ObjectId('5fcee5583090e67da89ca396'),
#  ObjectId('5fcee5583090e67da89ca397'),
#  ObjectId('5fcee5583090e67da89ca398'),
#  ObjectId('5fcee5583090e67da89ca399'),
#  ObjectId('5fcee5583090e67da89ca39a'),
#  ObjectId('5fcee5583090e67da89ca39b'),
#  ObjectId('5fcee5583090e67da89ca39c'),
#  ObjectId('5fcee5583090e67da89ca39d'),
#  ObjectId('5fcee5583090e67da89ca39e'),
#  ObjectId('5fcee5583090e67da89ca39f'),
#  ObjectId('5fcee5583090e67da89ca3a0'),
#  ObjectId('5fcee5583090e67da89ca3a1'),
#  ObjectId('5fcee5583090e67da89ca3a2'),
#  ObjectId('5fcee5583090e67da89ca3a3'),
#  ObjectId('5fcee5583090e67da89ca3a4'),
#  ObjectId('5fcee5583090e67da89ca3a5'),
#  ObjectId('5fcee5583090e67da89ca3a6'),
#  ObjectId('5fcee5583090e67da89ca3a7'),
#  ObjectId('5fcee5583090e67da89ca3a8'),
#  ObjectId('5fcee5583090e67da89ca3a9'),
#  ObjectId('5fcee5583090e67da89ca3aa'),
#  ObjectId('5fcee5583090e67da89ca3ab'),
#  ObjectId('5fcee5583090e67da89ca3ac'),
#  ObjectId('5fcee5583090e67da89ca3ad'),
#  ObjectId('5fcee5583090e67da89ca3ae'),
#  ObjectId('5fcee5583090e67da89ca3af'),
#  ObjectId('5fcee5583090e67da89ca3b0'),
#  ObjectId('5fcee5583090e67da89ca3b1'),
#  ObjectId('5fcee5583090e67da89ca3b2'),
#  ObjectId('5fcee5583090e67da89ca3b3'),
#  ObjectId('5fcee5583090e67da89ca3b4'),
#  ObjectId('5fcee5583090e67da89ca3b5'),
#  ObjectId('5fcee5583090e67da89ca3b6'),
#  ObjectId('5fcee5583090e67da89ca3b7'),
#  ObjectId('5fcee5583090e67da89ca3b8'),
#  ObjectId('5fcee5583090e67da89ca3b9'),
#  ObjectId('5fcee5583090e67da89ca3ba'),
#  ObjectId('5fcee5583090e67da89ca3bb'),
#  ObjectId('5fcee5583090e67da89ca3bc'),
#  ObjectId('5fcee5583090e67da89ca3bd'),
#  ObjectId('5fcee5583090e67da89ca3be'),
#  ObjectId('5fcee5583090e67da89ca3bf'),
#  ObjectId('5fcee5583090e67da89ca3c0'),
#  ObjectId('5fcee5583090e67da89ca3c1'),
#  ObjectId('5fcee5583090e67da89ca3c2'),
#  ObjectId('5fcee5583090e67da89ca3c3'),
#  ObjectId('5fcee5583090e67da89ca3c4'),
#  ObjectId('5fcee5583090e67da89ca3c5'),
#  ObjectId('5fcee5583090e67da89ca3c6'),
#  ObjectId('5fcee5583090e67da89ca3c7'),
#  ObjectId('5fcee5583090e67da89ca3c8'),
#  ObjectId('5fcee5583090e67da89ca3c9'),
#  ObjectId('5fcee5583090e67da89ca3ca'),
#  ObjectId('5fcee5583090e67da89ca3cb'),
#  ObjectId('5fcee5583090e67da89ca3cc'),
#  ObjectId('5fcee5583090e67da89ca3cd'),
#  ObjectId('5fcee5583090e67da89ca3ce'),
#  ObjectId('5fcee5583090e67da89ca3cf'),
#  ObjectId('5fcee5583090e67da89ca3d0'),
#  ObjectId('5fcee5583090e67da89ca3d1'),
#  ObjectId('5fcee5583090e67da89ca3d2'),
#  ObjectId('5fcee5583090e67da89ca3d3'),
#  ObjectId('5fcee5583090e67da89ca3d4'),
#  ObjectId('5fcee5583090e67da89ca3d5'),
#  ObjectId('5fcee5583090e67da89ca3d6'),
#  ObjectId('5fcee5583090e67da89ca3d7'),
#  ObjectId('5fcee5583090e67da89ca3d8'),
#  ObjectId('5fcee5583090e67da89ca3d9'),
#  ObjectId('5fcee5583090e67da89ca3da'),
#  ObjectId('5fcee5583090e67da89ca3db'),
#  ObjectId('5fcee5583090e67da89ca3dc'),
#  ObjectId('5fcee5583090e67da89ca3dd'),
#  ObjectId('5fcee5583090e67da89ca3de'),
#  ObjectId('5fcee5583090e67da89ca3df'),
#  ObjectId('5fcee5583090e67da89ca3e0'),
#  ObjectId('5fcee5583090e67da89ca3e1'),
#  ObjectId('5fcee5583090e67da89ca3e2'),
#  ObjectId('5fcee5583090e67da89ca3e3'),
#  ObjectId('5fcee5583090e67da89ca3e4'),
#  ObjectId('5fcee5583090e67da89ca3e5'),
#  ObjectId('5fcee5583090e67da89ca3e6'),
#  ObjectId('5fcee5583090e67da89ca3e7'),
#  ObjectId('5fcee5583090e67da89ca3e8'),
#  ObjectId('5fcee5583090e67da89ca3e9'),
#  ObjectId('5fcee5583090e67da89ca3ea'),
#  ObjectId('5fcee5583090e67da89ca3eb'),
#  ObjectId('5fcee5583090e67da89ca3ec'),
#  ObjectId('5fcee5583090e67da89ca3ed'),
#  ObjectId('5fcee5583090e67da89ca3ee'),
#  ObjectId('5fcee5583090e67da89ca3ef'),
#  ObjectId('5fcee5583090e67da89ca3f0'),
#  ObjectId('5fcee5583090e67da89ca3f1'),
#  ObjectId('5fcee5583090e67da89ca3f2'),
#  ObjectId('5fcee5583090e67da89ca3f3'),
#  ObjectId('5fcee5583090e67da89ca3f4'),
#  ObjectId('5fcee5583090e67da89ca3f5'),
#  ObjectId('5fcee5583090e67da89ca3f6'),
#  ObjectId('5fcee5583090e67da89ca3f7'),
#  ObjectId('5fcee5583090e67da89ca3f8'),
#  ObjectId('5fcee5583090e67da89ca3f9'),
#  ObjectId('5fcee5583090e67da89ca3fa'),
#  ObjectId('5fcee5583090e67da89ca3fb'),
#  ObjectId('5fcee5583090e67da89ca3fc'),
#  ObjectId('5fcee5583090e67da89ca3fd'),
#  ObjectId('5fcee5583090e67da89ca3fe'),
#  ObjectId('5fcee5583090e67da89ca3ff'),
#  ObjectId('5fcee5583090e67da89ca400'),
#  ObjectId('5fcee5583090e67da89ca401'),
#  ObjectId('5fcee5583090e67da89ca402'),
#  ObjectId('5fcee5583090e67da89ca403'),
#  ObjectId('5fcee5583090e67da89ca404'),
#  ObjectId('5fcee5583090e67da89ca405'),
#  ObjectId('5fcee5583090e67da89ca406'),
#  ObjectId('5fcee5583090e67da89ca407'),
#  ObjectId('5fcee5583090e67da89ca408'),
#  ObjectId('5fcee5583090e67da89ca409'),
#  ObjectId('5fcee5583090e67da89ca40a'),
#  ObjectId('5fcee5583090e67da89ca40b'),
#  ObjectId('5fcee5583090e67da89ca40c'),
#  ObjectId('5fcee5583090e67da89ca40d'),
#  ObjectId('5fcee5583090e67da89ca40e'),
#  ObjectId('5fcee5583090e67da89ca40f'),
#  ObjectId('5fcee5583090e67da89ca410'),
#  ObjectId('5fcee5583090e67da89ca411'),
#  ObjectId('5fcee5583090e67da89ca412'),
#  ObjectId('5fcee5583090e67da89ca413'),
#  ObjectId('5fcee5583090e67da89ca414'),
#  ObjectId('5fcee5583090e67da89ca415'),
#  ObjectId('5fcee5583090e67da89ca416'),
#  ObjectId('5fcee5583090e67da89ca417'),
#  ObjectId('5fcee5583090e67da89ca418'),
#  ObjectId('5fcee5583090e67da89ca419'),
#  ObjectId('5fcee5583090e67da89ca41a'),
#  ObjectId('5fcee5583090e67da89ca41b'),
#  ObjectId('5fcee5583090e67da89ca41c'),
#  ObjectId('5fcee5583090e67da89ca41d'),
#  ObjectId('5fcee5583090e67da89ca41e'),
#  ObjectId('5fcee5583090e67da89ca41f'),
#  ObjectId('5fcee5583090e67da89ca420'),
#  ObjectId('5fcee5583090e67da89ca421'),
#  ObjectId('5fcee5583090e67da89ca422'),
#  ObjectId('5fcee5583090e67da89ca423'),
#  ObjectId('5fcee5583090e67da89ca424'),
#  ObjectId('5fcee5583090e67da89ca425'),
#  ObjectId('5fcee5583090e67da89ca426'),
#  ObjectId('5fcee5583090e67da89ca427'),
#  ObjectId('5fcee5583090e67da89ca428'),
#  ObjectId('5fcee5583090e67da89ca429'),
#  ObjectId('5fcee5583090e67da89ca42a'),
#  ObjectId('5fcee5583090e67da89ca42b'),
#  ObjectId('5fcee5583090e67da89ca42c'),
#  ObjectId('5fcee5583090e67da89ca42d'),
#  ObjectId('5fcee5583090e67da89ca42e'),
#  ObjectId('5fcee5583090e67da89ca42f'),
#  ObjectId('5fcee5583090e67da89ca430'),
#  ObjectId('5fcee5583090e67da89ca431'),
#  ObjectId('5fcee5583090e67da89ca432'),
#  ObjectId('5fcee5583090e67da89ca433'),
#  ObjectId('5fcee5583090e67da89ca434'),
#  ObjectId('5fcee5583090e67da89ca435'),
#  ObjectId('5fcee5583090e67da89ca436'),
#  ObjectId('5fcee5583090e67da89ca437'),
#  ObjectId('5fcee5583090e67da89ca438'),
#  ObjectId('5fcee5583090e67da89ca439'),
#  ObjectId('5fcee5583090e67da89ca43a'),
#  ObjectId('5fcee5583090e67da89ca43b'),
#  ObjectId('5fcee5583090e67da89ca43c'),
#  ObjectId('5fcee5583090e67da89ca43d'),
#  ObjectId('5fcee5583090e67da89ca43e'),
#  ObjectId('5fcee5583090e67da89ca43f'),
#  ObjectId('5fcee5583090e67da89ca440'),
#  ObjectId('5fcee5583090e67da89ca441'),
#  ObjectId('5fcee5583090e67da89ca442'),
#  ObjectId('5fcee5583090e67da89ca443'),
#  ObjectId('5fcee5583090e67da89ca444'),
#  ObjectId('5fcee5583090e67da89ca445'),
#  ObjectId('5fcee5583090e67da89ca446'),
#  ObjectId('5fcee5583090e67da89ca447'),
#  ObjectId('5fcee5583090e67da89ca448'),
#  ObjectId('5fcee5583090e67da89ca449'),
#  ObjectId('5fcee5583090e67da89ca44a'),
#  ObjectId('5fcee5583090e67da89ca44b'),
#  ObjectId('5fcee5583090e67da89ca44c'),
#  ObjectId('5fcee5583090e67da89ca44d'),
#  ObjectId('5fcee5583090e67da89ca44e'),
#  ObjectId('5fcee5583090e67da89ca44f'),
#  ObjectId('5fcee5583090e67da89ca450'),
#  ObjectId('5fcee5583090e67da89ca451'),
#  ObjectId('5fcee5583090e67da89ca452'),
#  ObjectId('5fcee5583090e67da89ca453'),
#  ObjectId('5fcee5583090e67da89ca454'),
#  ObjectId('5fcee5583090e67da89ca455'),
#  ObjectId('5fcee5583090e67da89ca456'),
#  ObjectId('5fcee5583090e67da89ca457'),
#  ObjectId('5fcee5583090e67da89ca458'),
#  ObjectId('5fcee5583090e67da89ca459'),
#  ObjectId('5fcee5583090e67da89ca45a'),
#  ObjectId('5fcee5583090e67da89ca45b'),
#  ObjectId('5fcee5583090e67da89ca45c'),
#  ObjectId('5fcee5583090e67da89ca45d'),
#  ObjectId('5fcee5583090e67da89ca45e'),
#  ObjectId('5fcee5583090e67da89ca45f'),
#  ObjectId('5fcee5583090e67da89ca460'),
#  ObjectId('5fcee5583090e67da89ca461'),
#  ObjectId('5fcee5583090e67da89ca462'),
#  ObjectId('5fcee5583090e67da89ca463'),
#  ObjectId('5fcee5583090e67da89ca464'),
#  ObjectId('5fcee5583090e67da89ca465'),
#  ObjectId('5fcee5583090e67da89ca466'),
#  ObjectId('5fcee5583090e67da89ca467'),
#  ObjectId('5fcee5583090e67da89ca468'),
#  ObjectId('5fcee5583090e67da89ca469'),
#  ObjectId('5fcee5583090e67da89ca46a'),
#  ObjectId('5fcee5583090e67da89ca46b'),
#  ObjectId('5fcee5583090e67da89ca46c'),
#  ObjectId('5fcee5583090e67da89ca46d'),
#  ObjectId('5fcee5583090e67da89ca46e'),
#  ObjectId('5fcee5583090e67da89ca46f'),
#  ObjectId('5fcee5583090e67da89ca470'),
#  ObjectId('5fcee5583090e67da89ca471'),
#  ObjectId('5fcee5583090e67da89ca472'),
#  ObjectId('5fcee5583090e67da89ca473'),
#  ObjectId('5fcee5583090e67da89ca474'),
#  ObjectId('5fcee5583090e67da89ca475'),
#  ObjectId('5fcee5583090e67da89ca476'),
#  ObjectId('5fcee5583090e67da89ca477'),
#  ObjectId('5fcee5583090e67da89ca478'),
#  ObjectId('5fcee5583090e67da89ca479'),
#  ObjectId('5fcee5583090e67da89ca47a'),
#  ObjectId('5fcee5583090e67da89ca47b'),
#  ObjectId('5fcee5583090e67da89ca47c'),
#  ObjectId('5fcee5583090e67da89ca47d'),
#  ObjectId('5fcee5583090e67da89ca47e'),
#  ObjectId('5fcee5583090e67da89ca47f'),
#  ObjectId('5fcee5583090e67da89ca480'),
#  ObjectId('5fcee5583090e67da89ca481'),
#  ObjectId('5fcee5583090e67da89ca482'),
#  ObjectId('5fcee5583090e67da89ca483'),
#  ObjectId('5fcee5583090e67da89ca484'),
#  ObjectId('5fcee5583090e67da89ca485'),
#  ObjectId('5fcee5583090e67da89ca486'),
#  ObjectId('5fcee5583090e67da89ca487'),
#  ObjectId('5fcee5583090e67da89ca488'),
#  ObjectId('5fcee5583090e67da89ca489'),
#  ObjectId('5fcee5583090e67da89ca48a'),
#  ObjectId('5fcee5583090e67da89ca48b'),
#  ObjectId('5fcee5583090e67da89ca48c'),
#  ObjectId('5fcee5583090e67da89ca48d'),
#  ObjectId('5fcee5583090e67da89ca48e'),
#  ObjectId('5fcee5583090e67da89ca48f'),
#  ObjectId('5fcee5583090e67da89ca490'),
#  ObjectId('5fcee5583090e67da89ca491'),
#  ObjectId('5fcee5583090e67da89ca492'),
#  ObjectId('5fcee5583090e67da89ca493'),
#  ObjectId('5fcee5583090e67da89ca494'),
#  ObjectId('5fcee5583090e67da89ca495'),
#  ObjectId('5fcee5583090e67da89ca496'),
#  ObjectId('5fcee5583090e67da89ca497'),
#  ObjectId('5fcee5583090e67da89ca498'),
#  ObjectId('5fcee5583090e67da89ca499'),
#  ObjectId('5fcee5583090e67da89ca49a'),
#  ObjectId('5fcee5583090e67da89ca49b'),
#  ObjectId('5fcee5583090e67da89ca49c'),
#  ObjectId('5fcee5583090e67da89ca49d'),
#  ObjectId('5fcee5583090e67da89ca49e'),
#  ObjectId('5fcee5583090e67da89ca49f'),
#  ObjectId('5fcee5583090e67da89ca4a0'),
#  ObjectId('5fcee5583090e67da89ca4a1'),
#  ObjectId('5fcee5583090e67da89ca4a2'),
#  ObjectId('5fcee5583090e67da89ca4a3'),
#  ObjectId('5fcee5583090e67da89ca4a4'),
#  ObjectId('5fcee5583090e67da89ca4a5'),
#  ObjectId('5fcee5583090e67da89ca4a6'),
#  ObjectId('5fcee5583090e67da89ca4a7'),
#  ObjectId('5fcee5583090e67da89ca4a8'),
#  ObjectId('5fcee5583090e67da89ca4a9'),
#  ObjectId('5fcee5583090e67da89ca4aa'),
#  ObjectId('5fcee5583090e67da89ca4ab'),
#  ObjectId('5fcee5583090e67da89ca4ac'),
#  ObjectId('5fcee5583090e67da89ca4ad'),
#  ObjectId('5fcee5583090e67da89ca4ae'),
#  ObjectId('5fcee5583090e67da89ca4af'),
#  ObjectId('5fcee5583090e67da89ca4b0'),
#  ObjectId('5fcee5583090e67da89ca4b1'),
#  ObjectId('5fcee5583090e67da89ca4b2'),
#  ObjectId('5fcee5583090e67da89ca4b3'),
#  ObjectId('5fcee5583090e67da89ca4b4'),
#  ObjectId('5fcee5583090e67da89ca4b5'),
#  ObjectId('5fcee5583090e67da89ca4b6'),
#  ObjectId('5fcee5583090e67da89ca4b7'),
#  ObjectId('5fcee5583090e67da89ca4b8'),
#  ObjectId('5fcee5583090e67da89ca4b9'),
#  ObjectId('5fcee5583090e67da89ca4ba'),
#  ObjectId('5fcee5583090e67da89ca4bb'),
#  ObjectId('5fcee5583090e67da89ca4bc'),
#  ObjectId('5fcee5583090e67da89ca4bd'),
#  ObjectId('5fcee5583090e67da89ca4be'),
#  ObjectId('5fcee5583090e67da89ca4bf'),
#  ObjectId('5fcee5583090e67da89ca4c0'),
#  ObjectId('5fcee5583090e67da89ca4c1'),
#  ObjectId('5fcee5583090e67da89ca4c2'),
#  ObjectId('5fcee5583090e67da89ca4c3'),
#  ObjectId('5fcee5583090e67da89ca4c4'),
#  ObjectId('5fcee5583090e67da89ca4c5'),
#  ObjectId('5fcee5583090e67da89ca4c6'),
#  ObjectId('5fcee5583090e67da89ca4c7'),
#  ObjectId('5fcee5583090e67da89ca4c8'),
#  ObjectId('5fcee5583090e67da89ca4c9'),
#  ObjectId('5fcee5583090e67da89ca4ca'),
#  ObjectId('5fcee5583090e67da89ca4cb'),
#  ObjectId('5fcee5583090e67da89ca4cc'),
#  ObjectId('5fcee5583090e67da89ca4cd'),
#  ObjectId('5fcee5583090e67da89ca4ce'),
#  ObjectId('5fcee5583090e67da89ca4cf'),
#  ObjectId('5fcee5583090e67da89ca4d0'),
#  ObjectId('5fcee5583090e67da89ca4d1'),
#  ObjectId('5fcee5583090e67da89ca4d2'),
#  ObjectId('5fcee5583090e67da89ca4d3'),
#  ObjectId('5fcee5583090e67da89ca4d4'),
#  ObjectId('5fcee5583090e67da89ca4d5'),
#  ObjectId('5fcee5583090e67da89ca4d6'),
#  ObjectId('5fcee5583090e67da89ca4d7'),
#  ObjectId('5fcee5583090e67da89ca4d8'),
#  ObjectId('5fcee5583090e67da89ca4d9'),
#  ObjectId('5fcee5583090e67da89ca4da'),
#  ObjectId('5fcee5583090e67da89ca4db'),
#  ObjectId('5fcee5583090e67da89ca4dc'),
#  ObjectId('5fcee5583090e67da89ca4dd'),
#  ObjectId('5fcee5583090e67da89ca4de'),
#  ObjectId('5fcee5583090e67da89ca4df'),
#  ObjectId('5fcee5583090e67da89ca4e0'),
#  ObjectId('5fcee5583090e67da89ca4e1'),
#  ObjectId('5fcee5583090e67da89ca4e2'),
#  ObjectId('5fcee5583090e67da89ca4e3'),
#  ObjectId('5fcee5583090e67da89ca4e4'),
#  ObjectId('5fcee5583090e67da89ca4e5'),
#  ObjectId('5fcee5583090e67da89ca4e6'),
#  ObjectId('5fcee5583090e67da89ca4e7'),
#  ObjectId('5fcee5583090e67da89ca4e8'),
#  ObjectId('5fcee5583090e67da89ca4e9'),
#  ObjectId('5fcee5583090e67da89ca4ea'),
#  ObjectId('5fcee5583090e67da89ca4eb'),
#  ObjectId('5fcee5583090e67da89ca4ec'),
#  ObjectId('5fcee5583090e67da89ca4ed'),
#  ObjectId('5fcee5583090e67da89ca4ee'),
#  ObjectId('5fcee5583090e67da89ca4ef'),
#  ObjectId('5fcee5583090e67da89ca4f0'),
#  ObjectId('5fcee5583090e67da89ca4f1'),
#  ObjectId('5fcee5583090e67da89ca4f2'),
#  ObjectId('5fcee5583090e67da89ca4f3'),
#  ObjectId('5fcee5583090e67da89ca4f4'),
#  ObjectId('5fcee5583090e67da89ca4f5'),
#  ObjectId('5fcee5583090e67da89ca4f6'),
#  ObjectId('5fcee5583090e67da89ca4f7'),
#  ObjectId('5fcee5583090e67da89ca4f8'),
#  ObjectId('5fcee5583090e67da89ca4f9'),
#  ObjectId('5fcee5583090e67da89ca4fa'),
#  ObjectId('5fcee5583090e67da89ca4fb'),
#  ObjectId('5fcee5583090e67da89ca4fc'),
#  ObjectId('5fcee5583090e67da89ca4fd'),
#  ObjectId('5fcee5583090e67da89ca4fe'),
#  ObjectId('5fcee5583090e67da89ca4ff'),
#  ObjectId('5fcee5583090e67da89ca500'),
#  ObjectId('5fcee5583090e67da89ca501'),
#  ObjectId('5fcee5583090e67da89ca502'),
#  ObjectId('5fcee5583090e67da89ca503'),
#  ObjectId('5fcee5583090e67da89ca504'),
#  ObjectId('5fcee5583090e67da89ca505'),
#  ObjectId('5fcee5583090e67da89ca506'),
#  ObjectId('5fcee5583090e67da89ca507'),
#  ObjectId('5fcee5583090e67da89ca508'),
#  ObjectId('5fcee5583090e67da89ca509'),
#  ObjectId('5fcee5583090e67da89ca50a'),
#  ObjectId('5fcee5583090e67da89ca50b'),
#  ObjectId('5fcee5583090e67da89ca50c'),
#  ObjectId('5fcee5583090e67da89ca50d'),
#  ObjectId('5fcee5583090e67da89ca50e'),
#  ObjectId('5fcee5583090e67da89ca50f'),
#  ObjectId('5fcee5583090e67da89ca510'),
#  ObjectId('5fcee5583090e67da89ca511'),
#  ObjectId('5fcee5583090e67da89ca512'),
#  ObjectId('5fcee5583090e67da89ca513'),
#  ObjectId('5fcee5583090e67da89ca514'),
#  ObjectId('5fcee5583090e67da89ca515'),
#  ObjectId('5fcee5583090e67da89ca516'),
#  ObjectId('5fcee5583090e67da89ca517'),
#  ObjectId('5fcee5583090e67da89ca518'),
#  ObjectId('5fcee5583090e67da89ca519'),
#  ObjectId('5fcee5583090e67da89ca51a'),
#  ObjectId('5fcee5583090e67da89ca51b'),
#  ObjectId('5fcee5583090e67da89ca51c'),
#  ObjectId('5fcee5583090e67da89ca51d'),
#  ObjectId('5fcee5583090e67da89ca51e'),
#  ObjectId('5fcee5583090e67da89ca51f'),
#  ObjectId('5fcee5583090e67da89ca520'),
#  ObjectId('5fcee5583090e67da89ca521'),
#  ObjectId('5fcee5583090e67da89ca522'),
#  ObjectId('5fcee5583090e67da89ca523'),
#  ObjectId('5fcee5583090e67da89ca524'),
#  ObjectId('5fcee5583090e67da89ca525'),
#  ObjectId('5fcee5583090e67da89ca526'),
#  ObjectId('5fcee5583090e67da89ca527'),
#  ObjectId('5fcee5583090e67da89ca528'),
#  ObjectId('5fcee5583090e67da89ca529'),
#  ObjectId('5fcee5583090e67da89ca52a'),
#  ObjectId('5fcee5583090e67da89ca52b'),
#  ObjectId('5fcee5583090e67da89ca52c'),
#  ObjectId('5fcee5583090e67da89ca52d'),
#  ObjectId('5fcee5583090e67da89ca52e'),
#  ObjectId('5fcee5583090e67da89ca52f'),
#  ObjectId('5fcee5583090e67da89ca530'),
#  ObjectId('5fcee5583090e67da89ca531'),
#  ObjectId('5fcee5583090e67da89ca532'),
#  ObjectId('5fcee5583090e67da89ca533'),
#  ObjectId('5fcee5583090e67da89ca534'),
#  ObjectId('5fcee5583090e67da89ca535'),
#  ObjectId('5fcee5583090e67da89ca536'),
#  ObjectId('5fcee5583090e67da89ca537'),
#  ObjectId('5fcee5583090e67da89ca538'),
#  ObjectId('5fcee5583090e67da89ca539'),
#  ObjectId('5fcee5583090e67da89ca53a'),
#  ObjectId('5fcee5583090e67da89ca53b'),
#  ObjectId('5fcee5583090e67da89ca53c'),
#  ObjectId('5fcee5583090e67da89ca53d'),
#  ObjectId('5fcee5583090e67da89ca53e'),
#  ObjectId('5fcee5583090e67da89ca53f'),
#  ObjectId('5fcee5583090e67da89ca540'),
#  ObjectId('5fcee5583090e67da89ca541'),
#  ObjectId('5fcee5583090e67da89ca542'),
#  ObjectId('5fcee5583090e67da89ca543'),
#  ObjectId('5fcee5583090e67da89ca544'),
#  ObjectId('5fcee5583090e67da89ca545'),
#  ObjectId('5fcee5583090e67da89ca546'),
#  ObjectId('5fcee5583090e67da89ca547'),
#  ObjectId('5fcee5583090e67da89ca548'),
#  ObjectId('5fcee5583090e67da89ca549'),
#  ObjectId('5fcee5583090e67da89ca54a'),
#  ObjectId('5fcee5583090e67da89ca54b'),
#  ObjectId('5fcee5583090e67da89ca54c'),
#  ObjectId('5fcee5583090e67da89ca54d'),
#  ObjectId('5fcee5583090e67da89ca54e'),
#  ObjectId('5fcee5583090e67da89ca54f'),
#  ObjectId('5fcee5583090e67da89ca550'),
#  ObjectId('5fcee5583090e67da89ca551'),
#  ObjectId('5fcee5583090e67da89ca552'),
#  ObjectId('5fcee5583090e67da89ca553'),
#  ObjectId('5fcee5583090e67da89ca554'),
#  ObjectId('5fcee5583090e67da89ca555'),
#  ObjectId('5fcee5583090e67da89ca556'),
#  ObjectId('5fcee5583090e67da89ca557'),
#  ObjectId('5fcee5583090e67da89ca558'),
#  ObjectId('5fcee5583090e67da89ca559'),
#  ObjectId('5fcee5583090e67da89ca55a'),
#  ObjectId('5fcee5583090e67da89ca55b'),
#  ObjectId('5fcee5583090e67da89ca55c'),
#  ObjectId('5fcee5583090e67da89ca55d'),
#  ObjectId('5fcee5583090e67da89ca55e'),
#  ObjectId('5fcee5583090e67da89ca55f'),
#  ObjectId('5fcee5583090e67da89ca560'),
#  ObjectId('5fcee5583090e67da89ca561'),
#  ObjectId('5fcee5583090e67da89ca562'),
#  ObjectId('5fcee5583090e67da89ca563'),
#  ObjectId('5fcee5583090e67da89ca564'),
#  ObjectId('5fcee5583090e67da89ca565'),
#  ...]

# %%
db.bulk.count_documents({})
# Out:
# 10000

# %% [markdown]
# Mixed Bulk Write 작업
#
# 버전 2.7의 새로운 기능.
#
# PyMongo는 혼합 대량 쓰기 작업 실행도 지원합니다. 대량 쓰기 작업 API를 사용하여 삽입, 업데이트 및 제거 작업의 일괄 처리를 함께 실행할 수 있습니다.
#
# Ordered Bulk Write 작업
#
# 정렬된 대량 쓰기 작업은 일괄 처리되어 직렬 실행을 위해 제공된 순서대로 서버로 전송됩니다. 반환 값은 수행 된 작업의 유형과 개수를 설명하는 BulkWriteResult의 인스턴스입니다.

# %%
from pprint import pprint
from pymongo import InsertOne, DeleteMany, ReplaceOne, UpdateOne
result = db.bulk.bulk_write([
    DeleteMany({}), # Remove all documents from the previous example.
    InsertOne({'_id': 1}),
    InsertOne({'_id': 2}),
    InsertOne({'_id': 3}),
    UpdateOne({'_id': 1}, {'$set': {'foo': 'bar'}}),
    UpdateOne({'_id': 4}, {'$inc': {'j': 1}}, upsert=True),
    ReplaceOne({'j': 1}, {'j': 2})])
pprint(result.bulk_api_result)
# Out:
# {'nInserted': 3,
#  'nMatched': 2,
#  'nModified': 2,
#  'nRemoved': 4,
#  'nUpserted': 1,
#  'upserted': [{'_id': 4, 'index': 5}],
#  'writeConcernErrors': [],
#  'writeErrors': []}

# %% [markdown]
# 발생하는 첫 번째 쓰기 실패(예 : 중복 키 오류)는 나머지 작업을 중단하고 PyMongo는 BulkWriteError를 발생시킵니다. 예외 인스턴스의 세부 정보 속성은 실패가 발생하기 전까지의 실행 결과와 실패를 유발한 작업을 포함하여 실패에 대한 세부 정보를 제공합니다.

# %%
from pymongo import InsertOne, DeleteOne, ReplaceOne
from pymongo.errors import BulkWriteError
requests = [
    ReplaceOne({'j': 2}, {'i': 5}),
    InsertOne({'_id': 4}), # Violates the unique key constraint on _id.
    DeleteOne({'i': 5})]
try:
    db.bulk.bulk_write(requests)
except BulkWriteError as bwe:
    pprint(bwe.details)
# Out:
# {'nInserted': 0,
#  'nMatched': 0,
#  'nModified': 0,
#  'nRemoved': 0,
#  'nUpserted': 0,
#  'upserted': [],
#  'writeConcernErrors': [],
#  'writeErrors': [{'code': 11000,
#                   'errmsg': 'E11000 duplicate key error collection: '
#                             'bulk_example.bulk index: _id_ dup key: { _id: 4 }',
#                   'index': 1,
#                   'keyPattern': {'_id': 1},
#                   'keyValue': {'_id': 4},
#                   'op': {'_id': 4}}]}

# %% [markdown]
# 정렬되지 않은 Bulk Write 작업
#
# 정렬되지 않은 Bulk Write 작업은 일괄 처리되어 병렬로 실행될 수 있는 임의의 순서로 서버에 전송됩니다. 모든 작업이 시도 된 후에 발생하는 모든 오류가 보고 됩니다.
#
# 다음 예에서는 _id에 대한 고유 제약 조건으로 인해 첫 번째 및 세 번째 작업이 실패합니다. 순서가 지정되지 않은 실행을 수행하기 때문에 두 번째 및 네 번째 작업이 성공합니다.

# %%
requests = [
    InsertOne({'_id': 1}),
    DeleteOne({'_id': 2}),
    InsertOne({'_id': 3}),
    ReplaceOne({'_id': 4}, {'i': 1})]
try:
    db.bulk.bulk_write(requests, ordered=False)
except BulkWriteError as bwe:
    pprint(bwe.details)
# Out:
# {'nInserted': 0,
#  'nMatched': 1,
#  'nModified': 1,
#  'nRemoved': 1,
#  'nUpserted': 0,
#  'upserted': [],
#  'writeConcernErrors': [],
#  'writeErrors': [{'code': 11000,
#                   'errmsg': 'E11000 duplicate key error collection: '
#                             'bulk_example.bulk index: _id_ dup key: { _id: 1 }',
#                   'index': 0,
#                   'keyPattern': {'_id': 1},
#                   'keyValue': {'_id': 1},
#                   'op': {'_id': 1}},
#                  {'code': 11000,
#                   'errmsg': 'E11000 duplicate key error collection: '
#                             'bulk_example.bulk index: _id_ dup key: { _id: 3 }',
#                   'index': 2,
#                   'keyPattern': {'_id': 1},
#                   'keyValue': {'_id': 3},
#                   'op': {'_id': 3}}]}

# %% [markdown]
# Write Concern
#
# 대량 작업은 실행 되는 컬렉션의 write_concern으로 실행 됩니다. 쓰기 문제 오류 (예 : wtimeout)는 실행 순서에 관계없이 모든 작업이 시도 된 후에 보고 됩니다.

# %%
from pymongo import WriteConcern
coll = db.get_collection(
     'test', write_concern=WriteConcern(w=3, wtimeout=1))
try:
    coll.bulk_write([InsertOne({'a': i}) for i in range(4)])
except BulkWriteError as bwe:
    pprint(bwe.details)
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# <ipython-input-18-d8fabd4cf388> in <module>
#       3      'test', write_concern=WriteConcern(w=3, wtimeout=1))
#       4 try:
# ----> 5     coll.bulk_write([InsertOne({'a': i}) for i in range(4)])
#       6 except BulkWriteError as bwe:
#       7     pprint(bwe.details)
#
# /opt/conda/lib/python3.7/site-packages/pymongo/collection.py in bulk_write(self, requests, ordered, bypass_document_validation, session)
#     503
#     504         write_concern = self._write_concern_for(session)
# --> 505         bulk_api_result = blk.execute(write_concern, session)
#     506         if bulk_api_result is not None:
#     507             return BulkWriteResult(bulk_api_result, True)
#
# /opt/conda/lib/python3.7/site-packages/pymongo/bulk.py in execute(self, write_concern, session)
#     526                 self.execute_no_results(sock_info, generator)
#     527         else:
# --> 528             return self.execute_command(generator, write_concern, session)
#     529
#     530
#
# /opt/conda/lib/python3.7/site-packages/pymongo/bulk.py in execute_command(self, generator, write_concern, session)
#     358         with client._tmp_session(session) as s:
#     359             client._retry_with_session(
# --> 360                 self.is_retryable, retryable_bulk, s, self)
#     361
#     362         if full_result["writeErrors"] or full_result["writeConcernErrors"]:
#
# /opt/conda/lib/python3.7/site-packages/pymongo/mongo_client.py in _retry_with_session(self, retryable, func, session, bulk)
#    1382         retryable = (retryable and self.retry_writes
#    1383                      and session and not session.in_transaction)
# -> 1384         return self._retry_internal(retryable, func, session, bulk)
#    1385
#    1386     def _retry_internal(self, retryable, func, session, bulk):
#
# /opt/conda/lib/python3.7/site-packages/pymongo/mongo_client.py in _retry_internal(self, retryable, func, session, bulk)
#    1414                             raise last_error
#    1415                         retryable = False
# -> 1416                     return func(session, sock_info, retryable)
#    1417             except ServerSelectionTimeoutError:
#    1418                 if is_retrying():
#
# /opt/conda/lib/python3.7/site-packages/pymongo/bulk.py in retryable_bulk(session, sock_info, retryable)
#     353             self._execute_command(
#     354                 generator, write_concern, session, sock_info, op_id,
# --> 355                 retryable, full_result)
#     356
#     357         client = self.collection.database.client
#
# /opt/conda/lib/python3.7/site-packages/pymongo/bulk.py in _execute_command(self, generator, write_concern, session, sock_info, op_id, retryable, full_result)
#     307                 ops = islice(run.ops, run.idx_offset, None)
#     308                 # Run as many ops as possible in one command.
# --> 309                 result, to_send = bwc.execute(ops, client)
#     310
#     311                 # Retryable writeConcernErrors halt the execution of this run.
#
# /opt/conda/lib/python3.7/site-packages/pymongo/message.py in execute(self, docs, client)
#     905     def execute(self, docs, client):
#     906         request_id, msg, to_send = self._batch_command(docs)
# --> 907         result = self.write_command(request_id, msg, to_send)
#     908         client._process_response(result, self.session)
#     909         return result, to_send
#
# /opt/conda/lib/python3.7/site-packages/pymongo/message.py in write_command(self, request_id, msg, docs)
#     997             start = datetime.datetime.now()
#     998         try:
# --> 999             reply = self.sock_info.write_command(request_id, msg)
#    1000             if self.publish:
#    1001                 duration = (datetime.datetime.now() - start) + duration
#
# /opt/conda/lib/python3.7/site-packages/pymongo/pool.py in write_command(self, request_id, msg)
#     769
#     770         # Raises NotMasterError or OperationFailure.
# --> 771         helpers._check_command_response(result, self.max_wire_version)
#     772         return result
#     773
#
# /opt/conda/lib/python3.7/site-packages/pymongo/helpers.py in _check_command_response(response, max_wire_version, allowable_errors, parse_write_concern_error)
#     158         raise CursorNotFound(errmsg, code, response, max_wire_version)
#     159
# --> 160     raise OperationFailure(errmsg, code, response, max_wire_version)
#     161
#     162
#
# OperationFailure: cannot use 'w' > 1 when a host is not replicated, full error: {'ok': 0.0, 'errmsg': "cannot use 'w' > 1 when a host is not replicated", 'code': 2, 'codeName': 'BadValue'}
