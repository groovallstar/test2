# %% [markdown]
# <a href="https://colab.research.google.com/github/groovallstar/test2/blob/develop/urllib_tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import urllib.request

def request(url) :
  response = urllib.request.urlopen(url)
  byte_data = response.read()
  text_data = byte_data.decode('utf-8')
  return text_data

#print(request('https://python.bakyeono.net'))
"""
url = 'https://python.bakyeono.net/data/movies.json'
text_data = urllib.request.urlopen(url).read().decode('utf-8')
print(text_data)
"""
"""
url = 'https://python.bakyeono.net/data/movies.json'
url_parts = urllib.parse.urlsplit(url)
print(url_parts[0]) # protocol
print(url_parts[1]) # host
print(url_parts[2]) # sub path
"""
"""
url_parts = list(url_parts)
url_parts[2] = '/chapter-11.html'
urllib.parse.urlunsplit(url_parts)
print(url_parts)
"""
#urllib.parse.quote('파이썬')
#urllib.parse.unquote('%ED%8C%8C%EC%9D%B4%EC%8D%AC')
base_url = 'https://ko.wikipedia.org'
path = urllib.parse.quote('/wiki/파이썬')
url = base_url + path
urllib.request.urlopen(url).read().decode('utf-8')
# Out:
# '<!DOCTYPE html>\n<html class="client-nojs" lang="ko" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>파이썬 - 위키백과, 우리 모두의 백과사전</title>\n<script>document.documentElement.className="client-js";RLCONF={"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"파이썬","wgTitle":"파이썬","wgCurRevisionId":24937858,"wgRevisionId":24937858,"wgArticleId":6653,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["출처가 필요한 글","출처가 필요한 글/2013년 4월","CS1 - 영어 인용 (en)","영어 표기를 포함한 문서","BNF 식별자를 포함한 위키백과 문서","GND 식별자를 포함한 위키백과 문서","LCCN 식별자를 포함한 위키백과 문서","SUDOC 식별자를 포함한 위키백과 문서","파이썬","객체 지향 프로그래밍 언어","스크립트 언어","자유 소프트웨어","크로스 플랫폼 소프트웨어","네덜란드의 발명품","1991년 개발된 프로그래밍 언어","교육용 프로그래밍 언어","크로스 플랫폼 자유 소프트웨어"],"wgBreakFrames":\n!1,"wgPageContentLanguage":"ko","wgPageContentModel":"wikitext","wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"ko","wgMonthNames":["","1월","2월","3월","
# ...
