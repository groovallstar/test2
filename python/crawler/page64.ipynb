# %% [markdown]
# <a href="https://colab.research.google.com/github/groovallstar/test2/blob/feature%2Ffrom_colab/page64.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re
import datetime
import random

'''
random.seed(datetime.datetime.now())

def getLinks(articleUrl):
  html = urlopen('http://en.wikipedia.org{}'.format(articleUrl))
  bs = BeautifulSoup(html, 'html.parser')
  return bs.find('div', {'id':'bodyContent'}).findAll('a',
                    href = re.compile('^(/wiki/)((?!:).)*$'))

links = getLinks('/wiki/Kevin_Bacon')
while len(links) > 0:
  newArticle = links[random.randint(0, len(links)-1)].attrs['href']
  print(newArticle)
  links = getLinks(newArticle)
'''
'''
html = urlopen('http://en.wikipedia.org/wiki/Kevin_Bacon')
bs = BeautifulSoup(html, 'html.parser')
for link in bs.findAll('a'):
  if 'href' in link.attrs:
    print(link.attrs['href'])
for link in bs.find('div', {'id':'bodyContent'}).findAll('a',
                    href = re.compile('^(/wiki/)((?!:).)*$')):
  if 'href' in link.attrs:
    print(link.attrs['href'])
'''

pages = set()
def getLinks(pageUrl):
  global pages
  html = urlopen('http://en.wikipedia.org{}'.format(pageUrl))
  bs = BeautifulSoup(html, 'html.parser')
  for link in bs.findAll('a', href=re.compile('^(/wiki/)')):
    if 'href' in link.attrs:
      if link.attrs['href'] not in pages:
        newPage = link.attrs['href']
        print(newPage)
        pages.add(newPage)
        getLinks(newPage)

getLinks('')
# Out:
# /wiki/Wikipedia
# /wiki/Wikipedia:Protection_policy#semi
# /wiki/Wikipedia:Requests_for_page_protection
# /wiki/Wikipedia:Protection_policy#move
# /wiki/Wikipedia:Lists_of_protected_pages
# /wiki/Wikipedia:Protection_policy
# /wiki/Wikipedia:Perennial_proposals
# /wiki/Wikipedia:Reliable_sources/Perennial_sources
# /wiki/Wikipedia:Reliable_sources
# /wiki/Wikipedia:WikiProject_Reliability
# /wiki/Wikipedia:WRE
# /wiki/File:People_icon.svg
# /wiki/Special:WhatLinksHere/File:People_icon.svg
# /wiki/Help:What_links_here
# /wiki/Wikipedia:Project_namespace#How-to_and_information_pages
# /wiki/Wikipedia:Policies_and_guidelines
# /wiki/Wikipedia:WikiProject_Politics
# /wiki/Wikipedia:WikiProject
# /wiki/Wikipedia:Wikimedia_sister_projects
# /wiki/Help:Interwikimedia_links
# /wiki/Help:Interlanguage_links
# /wiki/List_of_ISO_639-1_codes
# /wiki/File:Question_book-new.svg
# /wiki/Wikipedia:Protection_policy#full
# /wiki/Wikipedia:WPPP
# /wiki/File:People_icon_dead.svg
# /wiki/User:StevenDH
# /wiki/Wikipedia:User_pages
# /wiki/Wikipedia:Protection_policy#extended
# /wiki/Wikipedia:Party_and_person
# /wiki/File:Essay.svg
# /wiki/File:Essay.png
# /wiki/File:To_Commons.svg
# /wiki/Special:WhatLinksHere/File:To_Commons.svg
# /wiki/User_talk:Robert_Merkel
# /wiki/User_talk:Robert_Merkel/ancient
# /wiki/User:RjLesch
# /wiki/Des_Moines,_Iowa
# /wiki/Des_Moines_(disambiguation)
# /wiki/Des_Moines_metropolitan_area
# /wiki/Geographic_coordinate_system
# /wiki/Template:Coord
# /wiki/Wikipedia:Protection_policy#template
# /wiki/Wikipedia:Child_protection
# /wiki/Wikipedia:Biographies_of_living_persons
# /wiki/Wikipedia:Biographies_of_living_persons/Noticeboard
# /wiki/Template:Noticeboard_links
# /wiki/Template_talk:Noticeboard_links
# /wiki/Wikipedia:Talk_page_guidelines
# /wiki/Help:Talk_pages
# /wiki/Help:Template
# /wiki/Wikipedia:Template_messages
# /wiki/MOS:TM
# /wiki/Wikipedia:Manual_of_Style
# /wiki/Wikipedia:Policies_and_guidelines#guide
# /wiki/Wikipedia:List_of_policies#Procedural
# /wiki/Template:Nutshell
# /wiki/Template:Nutshell/doc
# /wiki/Wikipedia:Template_documentation
# /wiki/File:Twemoji_1f527.svg
# /wiki/Special:WhatLinksHere/File:Twemoji_1f527.svg
# /wiki/Help:Editing
# /wiki/Wikipedia:Editing_policy
# /wiki/Wikipedia:List_of_guidelines#Editing
# /wiki/Wikipedia:List_of_policies
# /wiki/Wikipedia_talk:List_of_policies
# /wiki/File:Peacedove.svg
# /wiki/Special:WhatLinksHere/File:Peacedove.svg
# /wiki/Talk:Kashmir
# /wiki/Kashmir
# /wiki/Kashmar
# /wiki/Kashmar_County
# /wiki/Counties_of_Iran
# /wiki/File:Iran_Counties.svg
# /wiki/County
# /wiki/Country
# /wiki/Country_(disambiguation)
# /wiki/Rural_area
# /wiki/Rural_(disambiguation)
# /wiki/Rural
# /wiki/File:Barossa_Valley_South_Australia.jpg
# /wiki/Australian_wine
# /wiki/File:Australian_Wine.jpg
# /wiki/Canon_(company)
# /wiki/File:Canon_wordmark.svg
# /wiki/Canon_7
# /wiki/File:Canon_7_with_50mm_f0.95_IMG_0374.JPG
# /wiki/User:Rama
# /wiki/File:EU_carry_on.svg
# /wiki/Special:MyTalk
# /wiki/Case_sensitivity
# /wiki/String_(computer_science)
# /wiki/String_(disambiguation)
# /wiki/String_(structure)
# /wiki/Structure
# /wiki/Structure_(disambiguation)
# /wiki/Architectural_structure
# /wiki/File:20071123_Ratner_Center.jpg
# /wiki/Ratner_Center
# /wiki/Wikipedia:Good_articles
# /wiki/Wikipedia:Good_article_criteria
# /wiki/Wikipedia:Good_article_nominations
# /wiki/Wikipedia_talk:Good_article_nominations
# /wiki/Wikipedia:Good_article_nominations/Instructions
# /wiki/Wikipedia:Good_article_reassessment
# /wiki/Category:Wikipedia_backlog
# /wiki/Help:Category
# /wiki/Wikipedia:Categorization
# /wiki/Wikipedia:WikiProject_Cats
# /wiki/Wikipedia:CATP
# /wiki/Wikipedia:WikiProject_Council/Guide
# /wiki/Wikipedia:WikiProject_Council
# /wiki/Wikipedia:Shortcut
# /wiki/Wikipedia:Keyboard_shortcuts
# /wiki/Wikipedia:WikiProject_Kansas
# /wiki/Wikipedia:WikiProject_Council/Directory
# /wiki/Wikipedia:Community_portal
# /wiki/Wikipedia:Dashboard
# /wiki/Wikipedia:Department_directory
# /wiki/Wikipedia:Directory
# /wiki/Wikipedia:DIRECTORY
# /wiki/Wikipedia:Notability
# /wiki/Wikipedia:NPOV
# /wiki/Wikipedia:Describing_points_of_view
# /wiki/Wikipedia:NOTOPINION
# /wiki/Wikipedia:Glossary
# /wiki/Wikipedia:Wikipedia_abbreviations
# /wiki/Wikipedia:Manual_of_Style/Abbreviations
# /wiki/Wikipedia:List_of_shortcuts
# /wiki/Wikipedia:About
# /wiki/Wikipedia:Five_pillars
# /wiki/File:Encyclopedia_icon.svg
# /wiki/User:Afents/sandbox
# /wiki/User:Afents
# /wiki/Special:MyContributions
# /wiki/Help:User_contributions
# /wiki/Wikipedia:Project_namespace#Wikipedia_how-to_and_information_pages
# /wiki/Wikipedia:WikipediaSpace
# /wiki/File:WikipediaSpace-WS1-Introduction-v1.pdf
# /wiki/Main_Page
# /wiki/Free_content
# /wiki/Wikipedia:Protection_policy#pending
# /wiki/Wikipedia:WikiProject_Protected_areas
# /wiki/File:Roseberry_topping_north_side.jpg
# /wiki/Roseberry_Topping
# /wiki/Summit
# /wiki/Summit_(meeting)
# /wiki/Head_of_state
# /wiki/Head_of_government
# /wiki/Wikipedia:Verifiability
# /wiki/Wikipedia:Reliable_sources/Noticeboard
# /wiki/Wikipedia:Noticeboards
# /wiki/Wikipedia:Consensus#Levels_of_consensus
# /wiki/Wikipedia:Conflict_of_interest
# /wiki/Wikipedia:Conflict_of_interest/Noticeboard
# /wiki/Wikipedia:WikiProject_Numismatics
# /wiki/Greek_language
# /wiki/Proto-Greek_language
# /wiki/Category:Indo-European
# /wiki/Indo-European_languages
# /wiki/Indo-European_(disambiguation)
# /wiki/Europe
# /wiki/European_Union
# /wiki/EU_(disambiguation)
# /wiki/.eu
# /wiki/File:Logo_.eu.svg
# /wiki/Portal:Contents
# /wiki/Portal_talk:Contents#Requested_move_9_October_2019
# /wiki/Wikipedia:Portal
# /wiki/Wikipedia:WikiProject_Portals
# /wiki/Portal:Contents/Portals
# /wiki/Portal:Contents/Overviews
# /wiki/Portal:Contents/Outlines
# /wiki/Portal:Contents/Lists
# /wiki/Portal:Contents/Glossaries
# /wiki/Portal:Contents/Categories
# /wiki/Portal:Contents/Indices
# /wiki/Portal:Contents/Reference
# /wiki/Portal:Contents/Culture_and_the_arts
# /wiki/Portal:Contents/Geography_and_places
# /wiki/Special:Nearby
# /wiki/Portal:Featured_content
# /wiki/File:Darkgreen_flag_waving.svg
# /wiki/Special:WhatLinksHere/File:Darkgreen_flag_waving.svg
# /wiki/Portal:Biology
# /wiki/Wikipedia:Featured_portals
# /wiki/Wikipedia:Village_pump_(proposals)/RfC:_Ending_the_system_of_portals
# /wiki/Wikipedia:Village_pump_(proposals)
# /wiki/Wikipedia:Village_pump_(policy)
# /wiki/Wikipedia:Village_pump_(technical)
# /wiki/Wikipedia:Village_pump_(idea_lab)
# /wiki/Wikipedia:Village_pump_(miscellaneous)
# /wiki/Wikipedia:Help_desk
# /wiki/Wikipedia:Administration
# /wiki/Wikipedia:Administrators
# /wiki/Wikipedia_administrators
# /wiki/File:Wikipedia_Administrator.svg
# /wiki/Special:WhatLinksHere/File:Wikipedia_Administrator.svg
# /wiki/User:XJaM
# /wiki/Society_of_Mathematicians,_Physicists_and_Astronomers_of_Slovenia
# /wiki/Slovene_language
# /wiki/Slovak_language
# /wiki/Talk:Slovak_language
# /wiki/Wikipedia:WikiProject_Languages
# /wiki/Wikipedia:Language
# /wiki/Wikipedia:Manual_of_Style/Accessibility#Other_languages
# /wiki/Wikipedia:WikiProject_Accessibility
# /wiki/Wikipedia:Collaborations
# /wiki/Wikipedia:Citation_overkill
# /wiki/Wikipedia:Oversight
# /wiki/Wikipedia:R#SUPPRESS
# /wiki/Wikipedia:WikiProject_Redirect
# /wiki/Wikipedia:Race_and_ethnicity
# /wiki/Wikipedia:Essays
# /wiki/Wikipedia:NOTESSAY
# /wiki/Wikipedia:What_%22Ignore_all_rules%22_means#Use_common_sense
# /wiki/Wikipedia:Ignore_all_rules
# /wiki/Wikipedia:Consensus
# /wiki/Help:Edit_conflict
# /wiki/Wikipedia:Edit_warring
# /wiki/Wikipedia:Administrators#Wheel_war
# /wiki/Wikipedia:Requests_for_administrator_attention
# /wiki/Wikipedia:Request_an_account
# /wiki/Wikipedia:Arbitration_Committee/Clerks
# /wiki/Wikipedia:Arbitration_Committee
# /wiki/Wikipedia:Arbitration/Requests
# /wiki/Wikipedia:Arbitration
# /wiki/Wikipedia:Dispute_resolution
# /wiki/Wikipedia:DR_(disambiguation)
# /wiki/Wikipedia:DR
# /wiki/Wikipedia:Abuse_Reports
# /wiki/Wikipedia:Edit_filter
# /wiki/Wikipedia:Article_Feedback_Tool
# /wiki/Wikipedia:HISPAGES
# /wiki/Category:Wikipedia_project_content_guidelines
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-88d959191619> in <module>()
#      45         getLinks(newPage)
#      46
# ---> 47 getLinks('')
#      48
#
# <ipython-input-12-88d959191619> in getLinks(pageUrl)
#      43         print(newPage)
#      44         pages.add(newPage)
# ---> 45         getLinks(newPage)
#      46
#      47 getLinks('')
#
# <ipython-input-12-88d959191619> in getLinks(pageUrl)
#      43         print(newPage)
#      44         pages.add(newPage)
# ---> 45         getLinks(newPage)
#      46
#      47 getLinks('')
#
# <ipython-input-12-88d959191619> in getLinks(pageUrl)
#      43         print(newPage)
#      44         pages.add(newPage)
# ---> 45         getLinks(newPage)
#      46
#      47 getLinks('')
#
# <ipython-input-12-88d959191619> in getLinks(pageUrl)
#      43         print(newPage)
#      44         pages.add(newPage)
# ---> 45         getLinks(newPage)
#      46
#      47 getLinks('')
#
# <ipython-input-12-88d959191619> in getLinks(pageUrl)
#      43         print(newPage)
#      44         pages.add(newPage)
# ---> 45         getLinks(newPage)
#      46
#      47 getLinks('')
#
# <ipython-input-12-88d959191619> in getLinks(pageUrl)
#      43         print(newPage)
#      44         pages.add(newPage)
# ---> 45         getLinks(newPage)
#      46
#      47 getLinks('')
#
# <ipython-input-12-88d959191619> in getLinks(pageUrl)
#      43         print(newPage)
#      44         pages.add(newPage)
# ---> 45         getLinks(newPage)
#      46
#      47 getLinks('')
#
# <ipython-input-12-88d959191619> in getLinks(pageUrl)
#      43         print(newPage)
#      44         pages.add(newPage)
# ---> 45         getLinks(newPage)
#      46
#      47 getLinks('')
#
# <ipython-input-12-88d959191619> in getLinks(pageUrl)
#      43         print(newPage)
#      44         pages.add(newPage)
# ---> 45         getLinks(newPage)
#      46
#      47 getLinks('')
#
# <ipython-input-12-88d959191619> in getLinks(pageUrl)
#      43         print(newPage)
#      44         pages.add(newPage)
# ---> 45         getLinks(newPage)
#      46
#      47 getLinks('')
#
# <ipython-input-12-88d959191619> in getLinks(pageUrl)
#      43         print(newPage)
#      44         pages.add(newPage)
# ---> 45         getLinks(newPage)
#      46
#      47 getLinks('')
#
# <ipython-input-12-88d959191619> in getLinks(pageUrl)
#      43         print(newPage)
#      44         pages.add(newPage)
# ---> 45         getLinks(newPage)
#      46
#      47 getLinks('')
#
# <ipython-input-12-88d959191619> in getLinks(pageUrl)
#      43         print(newPage)
#      44         pages.add(newPage)
# ---> 45         getLinks(newPage)
#      46
#      47 getLinks('')
#
# <ipython-input-12-88d959191619> in getLinks(pageUrl)
#      43         print(newPage)
#      44         pages.add(newPage)
# ---> 45         getLinks(newPage)
#      46
#      47 getLinks('')
#
# <ipython-input-12-88d959191619> in getLinks(pageUrl)
#      43         print(newPage)
#      44         pages.add(newPage)
# ---> 45         getLinks(newPage)
#      46
#      47 getLinks('')
#
# <ipython-input-12-88d959191619> in getLinks(pageUrl)
#      43         print(newPage)
#      44         pages.add(newPage)
# ---> 45         getLinks(newPage)
#      46
#      47 getLinks('')
#
# <ipython-input-12-88d959191619> in getLinks(pageUrl)
#      43         print(newPage)
#      44         pages.add(newPage)
# ---> 45         getLinks(newPage)
#      46
#      47 getLinks('')
#
# <ipython-input-12-88d959191619> in getLinks(pageUrl)
#      43         print(newPage)
#      44         pages.add(newPage)
# ---> 45         getLinks(newPage)
#      46
#      47 getLinks('')
#
# <ipython-input-12-88d959191619> in getLinks(pageUrl)
#      43         print(newPage)
#      44         pages.add(newPage)
# ---> 45         getLinks(newPage)
#      46
#      47 getLinks('')
#
# <ipython-input-12-88d959191619> in getLinks(pageUrl)
#      43         print(newPage)
#      44         pages.add(newPage)
# ---> 45         getLinks(newPage)
#      46
#      47 getLinks('')
#
# <ipython-input-12-88d959191619> in getLinks(pageUrl)
#      43         print(newPage)
#      44         pages.add(newPage)
# ---> 45         getLinks(newPage)
#      46
#      47 getLinks('')
#
# <ipython-input-12-88d959191619> in getLinks(pageUrl)
#      43         print(newPage)
#      44         pages.add(newPage)
# ---> 45         getLinks(newPage)
#      46
#      47 getLinks('')
#
# <ipython-input-12-88d959191619> in getLinks(pageUrl)
#      43         print(newPage)
#      44         pages.add(newPage)
# ---> 45         getLinks(newPage)
#      46
#      47 getLinks('')
#
# <ipython-input-12-88d959191619> in getLinks(pageUrl)
#      43         print(newPage)
#      44         pages.add(newPage)
# ---> 45         getLinks(newPage)
#      46
#      47 getLinks('')
#
# <ipython-input-12-88d959191619> in getLinks(pageUrl)
#      43         print(newPage)
#      44         pages.add(newPage)
# ---> 45         getLinks(newPage)
#      46
#      47 getLinks('')
#
# <ipython-input-12-88d959191619> in getLinks(pageUrl)
#      43         print(newPage)
#      44         pages.add(newPage)
# ---> 45         getLinks(newPage)
#      46
#      47 getLinks('')
#
# <ipython-input-12-88d959191619> in getLinks(pageUrl)
#      43         print(newPage)
#      44         pages.add(newPage)
# ---> 45         getLinks(newPage)
#      46
#      47 getLinks('')
#
# <ipython-input-12-88d959191619> in getLinks(pageUrl)
#      43         print(newPage)
#      44         pages.add(newPage)
# ---> 45         getLinks(newPage)
#      46
#      47 getLinks('')
#
# <ipython-input-12-88d959191619> in getLinks(pageUrl)
#      43         print(newPage)
#      44         pages.add(newPage)
# ---> 45         getLinks(newPage)
#      46
#      47 getLinks('')
#
# <ipython-input-12-88d959191619> in getLinks(pageUrl)
#      43         print(newPage)
#      44         pages.add(newPage)
# ---> 45         getLinks(newPage)
#      46
#      47 getLinks('')
#
# <ipython-input-12-88d959191619> in getLinks(pageUrl)
#      43         print(newPage)
#      44         pages.add(newPage)
# ---> 45         getLinks(newPage)
#      46
#      47 getLinks('')
#
# <ipython-input-12-88d959191619> in getLinks(pageUrl)
#      43         print(newPage)
#      44         pages.add(newPage)
# ---> 45         getLinks(newPage)
#      46
#      47 getLinks('')
#
# <ipython-input-12-88d959191619> in getLinks(pageUrl)
#      43         print(newPage)
#      44         pages.add(newPage)
# ---> 45         getLinks(newPage)
#      46
#      47 getLinks('')
#
# <ipython-input-12-88d959191619> in getLinks(pageUrl)
#      43         print(newPage)
#      44         pages.add(newPage)
# ---> 45         getLinks(newPage)
#      46
#      47 getLinks('')
#
# <ipython-input-12-88d959191619> in getLinks(pageUrl)
#      43         print(newPage)
#      44         pages.add(newPage)
# ---> 45         getLinks(newPage)
#      46
#      47 getLinks('')
#
# <ipython-input-12-88d959191619> in getLinks(pageUrl)
#      43         print(newPage)
#      44         pages.add(newPage)
# ---> 45         getLinks(newPage)
#      46
#      47 getLinks('')
#
# <ipython-input-12-88d959191619> in getLinks(pageUrl)
#      43         print(newPage)
#      44         pages.add(newPage)
# ---> 45         getLinks(newPage)
#      46
#      47 getLinks('')
#
# ... (169개의 스택 항목을 건너뛰었습니다. sys.last_value 및 sys.last_traceback을(를) 사용하여 자세히 검토하세요.) ...
# <ipython-input-12-88d959191619> in getLinks(pageUrl)
#      43         print(newPage)
#      44         pages.add(newPage)
# ---> 45         getLinks(newPage)
#      46
#      47 getLinks('')
#
# <ipython-input-12-88d959191619> in getLinks(pageUrl)
#      43         print(newPage)
#      44         pages.add(newPage)
# ---> 45         getLinks(newPage)
#      46
#      47 getLinks('')
#
# <ipython-input-12-88d959191619> in getLinks(pageUrl)
#      43         print(newPage)
#      44         pages.add(newPage)
# ---> 45         getLinks(newPage)
#      46
#      47 getLinks('')
#
# <ipython-input-12-88d959191619> in getLinks(pageUrl)
#      43         print(newPage)
#      44         pages.add(newPage)
# ---> 45         getLinks(newPage)
#      46
#      47 getLinks('')
#
# <ipython-input-12-88d959191619> in getLinks(pageUrl)
#      43         print(newPage)
#      44         pages.add(newPage)
# ---> 45         getLinks(newPage)
#      46
#      47 getLinks('')
#
# <ipython-input-12-88d959191619> in getLinks(pageUrl)
#      43         print(newPage)
#      44         pages.add(newPage)
# ---> 45         getLinks(newPage)
#      46
#      47 getLinks('')
#
# <ipython-input-12-88d959191619> in getLinks(pageUrl)
#      43         print(newPage)
#      44         pages.add(newPage)
# ---> 45         getLinks(newPage)
#      46
#      47 getLinks('')
#
# <ipython-input-12-88d959191619> in getLinks(pageUrl)
#      43         print(newPage)
#      44         pages.add(newPage)
# ---> 45         getLinks(newPage)
#      46
#      47 getLinks('')
#
# <ipython-input-12-88d959191619> in getLinks(pageUrl)
#      43         print(newPage)
#      44         pages.add(newPage)
# ---> 45         getLinks(newPage)
#      46
#      47 getLinks('')
#
# <ipython-input-12-88d959191619> in getLinks(pageUrl)
#      43         print(newPage)
#      44         pages.add(newPage)
# ---> 45         getLinks(newPage)
#      46
#      47 getLinks('')
#
# <ipython-input-12-88d959191619> in getLinks(pageUrl)
#      43         print(newPage)
#      44         pages.add(newPage)
# ---> 45         getLinks(newPage)
#      46
#      47 getLinks('')
#
# <ipython-input-12-88d959191619> in getLinks(pageUrl)
#      43         print(newPage)
#      44         pages.add(newPage)
# ---> 45         getLinks(newPage)
#      46
#      47 getLinks('')
#
# <ipython-input-12-88d959191619> in getLinks(pageUrl)
#      43         print(newPage)
#      44         pages.add(newPage)
# ---> 45         getLinks(newPage)
#      46
#      47 getLinks('')
#
# <ipython-input-12-88d959191619> in getLinks(pageUrl)
#      43         print(newPage)
#      44         pages.add(newPage)
# ---> 45         getLinks(newPage)
#      46
#      47 getLinks('')
#
# <ipython-input-12-88d959191619> in getLinks(pageUrl)
#      43         print(newPage)
#      44         pages.add(newPage)
# ---> 45         getLinks(newPage)
#      46
#      47 getLinks('')
#
# <ipython-input-12-88d959191619> in getLinks(pageUrl)
#      43         print(newPage)
#      44         pages.add(newPage)
# ---> 45         getLinks(newPage)
#      46
#      47 getLinks('')
#
# <ipython-input-12-88d959191619> in getLinks(pageUrl)
#      43         print(newPage)
#      44         pages.add(newPage)
# ---> 45         getLinks(newPage)
#      46
#      47 getLinks('')
#
# <ipython-input-12-88d959191619> in getLinks(pageUrl)
#      43         print(newPage)
#      44         pages.add(newPage)
# ---> 45         getLinks(newPage)
#      46
#      47 getLinks('')
#
# <ipython-input-12-88d959191619> in getLinks(pageUrl)
#      43         print(newPage)
#      44         pages.add(newPage)
# ---> 45         getLinks(newPage)
#      46
#      47 getLinks('')
#
# <ipython-input-12-88d959191619> in getLinks(pageUrl)
#      43         print(newPage)
#      44         pages.add(newPage)
# ---> 45         getLinks(newPage)
#      46
#      47 getLinks('')
#
# <ipython-input-12-88d959191619> in getLinks(pageUrl)
#      43         print(newPage)
#      44         pages.add(newPage)
# ---> 45         getLinks(newPage)
#      46
#      47 getLinks('')
#
# <ipython-input-12-88d959191619> in getLinks(pageUrl)
#      43         print(newPage)
#      44         pages.add(newPage)
# ---> 45         getLinks(newPage)
#      46
#      47 getLinks('')
#
# <ipython-input-12-88d959191619> in getLinks(pageUrl)
#      43         print(newPage)
#      44         pages.add(newPage)
# ---> 45         getLinks(newPage)
#      46
#      47 getLinks('')
#
# <ipython-input-12-88d959191619> in getLinks(pageUrl)
#      43         print(newPage)
#      44         pages.add(newPage)
# ---> 45         getLinks(newPage)
#      46
#      47 getLinks('')
#
# <ipython-input-12-88d959191619> in getLinks(pageUrl)
#      43         print(newPage)
#      44         pages.add(newPage)
# ---> 45         getLinks(newPage)
#      46
#      47 getLinks('')
#
# <ipython-input-12-88d959191619> in getLinks(pageUrl)
#      43         print(newPage)
#      44         pages.add(newPage)
# ---> 45         getLinks(newPage)
#      46
#      47 getLinks('')
#
# <ipython-input-12-88d959191619> in getLinks(pageUrl)
#      43         print(newPage)
#      44         pages.add(newPage)
# ---> 45         getLinks(newPage)
#      46
#      47 getLinks('')
#
# <ipython-input-12-88d959191619> in getLinks(pageUrl)
#      43         print(newPage)
#      44         pages.add(newPage)
# ---> 45         getLinks(newPage)
#      46
#      47 getLinks('')
#
# <ipython-input-12-88d959191619> in getLinks(pageUrl)
#      43         print(newPage)
#      44         pages.add(newPage)
# ---> 45         getLinks(newPage)
#      46
#      47 getLinks('')
#
# <ipython-input-12-88d959191619> in getLinks(pageUrl)
#      36   global pages
#      37   html = urlopen('http://en.wikipedia.org{}'.format(pageUrl))
# ---> 38   bs = BeautifulSoup(html, 'html.parser')
#      39   for link in bs.findAll('a', href=re.compile('^(/wiki/)')):
#      40     if 'href' in link.attrs:
#
# /usr/local/lib/python3.6/dist-packages/bs4/__init__.py in __init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, **kwargs)
#     280             self.reset()
#     281             try:
# --> 282                 self._feed()
#     283                 break
#     284             except ParserRejectedMarkup:
#
# /usr/local/lib/python3.6/dist-packages/bs4/__init__.py in _feed(self)
#     341         self.builder.reset()
#     342
# --> 343         self.builder.feed(self.markup)
#     344         # Close out any unfinished strings and close all the open tags.
#     345         self.endData()
#
# /usr/local/lib/python3.6/dist-packages/bs4/builder/_htmlparser.py in feed(self, markup)
#     245         parser.soup = self.soup
#     246         try:
# --> 247             parser.feed(markup)
#     248             parser.close()
#     249         except HTMLParseError as e:
#
# /usr/lib/python3.6/html/parser.py in feed(self, data)
#     109         """
#     110         self.rawdata = self.rawdata + data
# --> 111         self.goahead(0)
#     112
#     113     def close(self):
#
# /usr/lib/python3.6/html/parser.py in goahead(self, end)
#     169             if startswith('<', i):
#     170                 if starttagopen.match(rawdata, i): # < + letter
# --> 171                     k = self.parse_starttag(i)
#     172                 elif startswith("</", i):
#     173                     k = self.parse_endtag(i)
#
# /usr/lib/python3.6/html/parser.py in parse_starttag(self, i)
#     343             self.handle_startendtag(tag, attrs)
#     344         else:
# --> 345             self.handle_starttag(tag, attrs)
#     346             if tag in self.CDATA_CONTENT_ELEMENTS:
#     347                 self.set_cdata_mode(tag)
#
# /usr/local/lib/python3.6/dist-packages/bs4/builder/_htmlparser.py in handle_starttag(self, name, attrs, handle_empty_element)
#     100             attrvalue = '""'
#     101         #print "START", name
# --> 102         tag = self.soup.handle_starttag(name, None, None, attr_dict)
#     103         if tag and tag.is_empty_element and handle_empty_element:
#     104             # Unlike other parsers, html.parser doesn't send separate end tag
#
# /usr/local/lib/python3.6/dist-packages/bs4/__init__.py in handle_starttag(self, name, namespace, nsprefix, attrs)
#     518
#     519         tag = Tag(self, self.builder, name, namespace, nsprefix, attrs,
# --> 520                   self.currentTag, self._most_recent_element)
#     521         if tag is None:
#     522             return tag
#
# /usr/local/lib/python3.6/dist-packages/bs4/element.py in __init__(self, parser, builder, name, namespace, prefix, attrs, parent, previous, is_xml)
#     871     """Represents a found HTML tag with its attributes and contents."""
#     872
# --> 873     def __init__(self, parser=None, builder=None, name=None, namespace=None,
#     874                  prefix=None, attrs=None, parent=None, previous=None,
#     875                  is_xml=None):
#
# KeyboardInterrupt:
